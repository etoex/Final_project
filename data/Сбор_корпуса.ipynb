# %% [markdown]
# Этот ноутбук предназначен для сбора корпуса финских текстов из разных источников:
# - новостные сайты (Helsingin Sanomat, KU.fi, Heili и др.)
# - адаптированные книги на финском языке (PDF, DOCX)
#
# Цель: собрать разнообразные аутентичные и учебные тексты для дальнейшей обработки и генерации упражнений.
# В итоге целью было получить csv файл с текстами разных тематик и длины.

# %% [markdown]
# # Сбор корпуса их новостных сайтов

# %% [markdown]
# Почему было принято решение собирать именно тексты новостных сайтов?
#
# **Актуальный язык**:
# Новости отражают современный финский язык — лексику, фразеологию и грамматику, которые реально используются в обществе. При этом сочетается как формальный, так и разговорный стиль.
#
#
# **Разнообразие тем**:
# В новостях охватываются:
# политика, экология, технологии, медицина, культура и т.д.
# Это важно для обучения лексике по темам и тематического моделирования (LDA).
#
# **Формальный стиль**:
# Новостной язык чёткий, структурированный и часто грамматически корректен — хорошая основа для создания упражнений.
#
# **Большой объём и доступность**:
# Новости публикуются каждый день и легкодоступны для парсинга.

# %%
#импорт библиотек
import requests
from bs4 import BeautifulSoup
import time
import pandas as pd
from tqdm import tqdm
import re

# %% [markdown]
# 1. Helsingin Sanomat

# %%
#Указываем заголовки для запроса (чтобы сайт не заблокировал), и список рубрик для парсинга. Устанавливаем ограничения на количество статей (по факту, оно не пригодилось)
#рубрики были отобраны вручную, некоторые были также удалены из-за большого количества платного контента
HEADERS = {"User-Agent": "Mozilla/5.0"}
MAX_PER_RUBRIC = 150
MAX_TOTAL = 1000

rubrics = {
    "maailma": "https://www.hs.fi/maailma/",
    "paakirjoitukset": "https://www.hs.fi/paakirjoitukset/",
    "alueet": "https://www.hs.fi/alueet/",
    "suomi": "https://www.hs.fi/suomi/",
    "politiikka": "https://www.hs.fi/politiikka/",
    "helsinki": "https://www.hs.fi/helsinki/",
    "mielipide": "https://www.hs.fi/mielipide/",
}

#функция ищет все ссылки на статьи из заданной рубрики
def get_article_links(rubric_url, rubric_name, max_links=MAX_PER_RUBRIC):
    article_links = set()
    response = requests.get(rubric_url, headers=HEADERS, timeout=10)
    soup = BeautifulSoup(response.content, "html.parser")

    rubric_path = "/" + rubric_name + "/"

    for a in soup.find_all("a", href=True):
        href = a["href"]
        if rubric_path in href and "/art-" in href:
            full_url = "https://www.hs.fi" + href.split("?")[0] if href.startswith("/") else href
            article_links.add(full_url)
        if len(article_links) >= max_links:
            break
    return list(article_links)

#функция извлекает текст статьи с конкретной страницы
def get_article_text_hs(url):
    r = requests.get(url, headers=HEADERS, timeout=10)
    soup = BeautifulSoup(r.content, "html.parser")
    article = soup.find("article")
    if not article:
        return None

    paragraphs = article.find_all("p")
    text = "\n".join(p.get_text(strip=True) for p in paragraphs if p.get_text(strip=True))
    return text if len(text.split()) > 50 else None

#собираю все статьи: прохожусь по каждой рубрике, собираю ссылки и тексты, сохраняю их в список
total_saved = 0
articles = []

for rubric_name, rubric_url in rubrics.items():
    print(f"Рубрика: {rubric_name}")
    links = get_article_links(rubric_url, rubric_name, max_links=MAX_PER_RUBRIC)
    saved = 0
    i = 0
    while saved < MAX_PER_RUBRIC and i < len(links) and total_saved < MAX_TOTAL:
        url = links[i]
        text = get_article_text_hs(url)
        #на всякий случай делаю для себя вывод, что выводится именно тело статьи, а не заголовок или еще что-то.
        if saved == 1:
            print("\nПредпросмотр:")
            print("=" * 80)
            print(text[:1500])
            print("=" * 80)

        if text and len(text.split()) > 100:
            articles.append({
                "rubric": rubric_name,
                "url": url,
                "text": text
            })
            saved += 1
            total_saved += 1
            print(f"[{rubric_name}] {saved}: {url}")
        i += 1
        time.sleep(1.5)

    print(f"Сохранено {saved} статей из '{rubric_name}'\n")

#сохраняю в csv
df = pd.DataFrame(articles)
df.to_csv("hs_articles.csv", index=False, encoding="utf-8")
print(f"Всего сохранено: {total_saved} статей в hs_articles.csv")
# Out:
# Рубрика: maailma
# [maailma] 1: https://www.hs.fi/maailma/art-2000011350682.html
#
# Предпросмотр:
# ================================================================================
# Venäjän hyökkäys|Ukrainalaisten arvioiden mukaan jopa 80 prosenttia venäläisten lennokkien kriittisestä elektroniikasta on lähtöisin Kiinasta.
# Kiinan presidentti Xi Jinping ja Venäjän presidentti Vladimir Putin tapasivat toukokuussa Moskovassa.Kuva:Kirill Kudryavtsev / AFP
# Kiinan ulkoministeri Wang Yi kertoi, ettei Kiina voi hyväksyä Venäjän häviötä Ukrainan sodassa.
# Kiina tukee Venäjän sotateollisuutta toimittamalla elektroniikkaa ja muita tuotteita pakotteista huolimatta.
# Venäjällä ollaan kuitenkin huolissaan maan kasvavasta riippuvuudesta Kiinaan.
# KiinanulkoministeriWang Yikertoi torstaina, että Kiina ei voi hyväksyä tilannetta, jossa Venäjä häviäisi hyökkäyssotansa Ukrainassa.
# Ulkoministeri kertoi asiasta EU:n ulkosuhteiden- ja turvallisuuspolitiikan korkealle edustajalleKaja Kallaksellediplomaattien välisessä tapaamisessa.
# Asiasta kertoiuutiskanava CNNviitaten paikalla olleeseen viranomaislähteeseen. Lähteen mukaan lausunnon taustalla on Kiinan oma etu: mikäli Venäjä häviäisi sodan, Yhdysvallat voisi kohdistaa täyden huomionsa Kiinaan.
# Ulkoministerinlausunto on ristiriidassa Kiinan virallisen linjan kanssa. Kiina on julkisesti ilmoittanut olevansa Venäjän vuonna 2022 aloittamassa hyökkäyssodassa puolueeton.
# Kiinan ulkoministeriön tiedottaja toisti lausunnon puolueettomuudesta myös perjantaina, kun tältä kysyttiin ministerin lausunnoista.
# ”Kiinan lähtökohta Ukrainan kriisiin on objektiivinen ja johdonmukainen, eli neuvottelut, tulitauko ja rauha. Pitkittynyt Ukrainan krii
# ================================================================================
# [maailma] 2: https://www.hs.fi/maailma/art-2000011347931.html
# [maailma] 3: https://www.hs.fi/maailma/art-2000011354569.html
# [maailma] 4: https://www.hs.fi/maailma/art-2000011356631.html
# [maailma] 5: https://www.hs.fi/maailma/art-2000011354980.html
# [maailma] 6: https://www.hs.fi/maailma/art-2000011348928.html
# [maailma] 7: https://www.hs.fi/maailma/art-2000011349856.html
# [maailma] 8: https://www.hs.fi/maailma/art-2000011348000.html
# [maailma] 9: https://www.hs.fi/maailma/art-2000011348686.html
# [maailma] 10: https://www.hs.fi/maailma/art-2000011347816.html
# [maailma] 11: https://www.hs.fi/maailma/art-2000011344848.html
# [maailma] 12: https://www.hs.fi/maailma/art-2000011351460.html
# [maailma] 13: https://www.hs.fi/maailma/art-2000011342267.html
# [maailma] 14: https://www.hs.fi/maailma/art-2000011358412.html
# [maailma] 15: https://www.hs.fi/maailma/art-2000011347854.html
# [maailma] 16: https://www.hs.fi/maailma/art-2000011347683.html
# [maailma] 17: https://www.hs.fi/maailma/art-2000011354168.html
# [maailma] 18: https://www.hs.fi/maailma/art-2000011356599.html
# [maailma] 19: https://www.hs.fi/maailma/art-2000011348288.html
# [maailma] 20: https://www.hs.fi/maailma/art-2000011355947.html
# [maailma] 21: https://www.hs.fi/maailma/art-2000011358840.html
# [maailma] 22: https://www.hs.fi/maailma/art-2000011346853.html
# [maailma] 23: https://www.hs.fi/maailma/art-2000011352019.html
# [maailma] 24: https://www.hs.fi/maailma/art-2000011344779.html
# [maailma] 25: https://www.hs.fi/maailma/art-2000011349633.html
# [maailma] 26: https://www.hs.fi/maailma/art-2000011348081.html
# [maailma] 27: https://www.hs.fi/maailma/art-2000011351791.html
# [maailma] 28: https://www.hs.fi/maailma/art-2000011352692.html
# [maailma] 29: https://www.hs.fi/maailma/art-2000011359035.html
# [maailma] 30: https://www.hs.fi/maailma/art-2000011352978.html
# [maailma] 31: https://www.hs.fi/maailma/art-2000011356917.html
# [maailma] 32: https://www.hs.fi/maailma/art-2000011357947.html
# [maailma] 33: https://www.hs.fi/maailma/art-2000011353913.html
# [maailma] 34: https://www.hs.fi/maailma/art-2000011349239.html
# [maailma] 35: https://www.hs.fi/maailma/art-2000011348637.html
# [maailma] 36: https://www.hs.fi/maailma/art-2000011344391.html
# [maailma] 37: https://www.hs.fi/maailma/art-2000011339792.html
# [maailma] 38: https://www.hs.fi/maailma/art-2000011344538.html
# [maailma] 39: https://www.hs.fi/maailma/art-2000011348732.html
# [maailma] 40: https://www.hs.fi/maailma/art-2000011354440.html
# [maailma] 41: https://www.hs.fi/maailma/art-2000011351324.html
# [maailma] 42: https://www.hs.fi/maailma/art-2000011356541.html
# [maailma] 43: https://www.hs.fi/maailma/art-2000011348695.html
# [maailma] 44: https://www.hs.fi/maailma/art-2000011356553.html
# [maailma] 45: https://www.hs.fi/maailma/art-2000011344715.html
# [maailma] 46: https://www.hs.fi/maailma/art-2000011354308.html
# [maailma] 47: https://www.hs.fi/maailma/art-2000011354794.html
# [maailma] 48: https://www.hs.fi/maailma/art-2000011348685.html
# [maailma] 49: https://www.hs.fi/maailma/art-2000011355209.html
# [maailma] 50: https://www.hs.fi/maailma/art-2000011356511.html
# [maailma] 51: https://www.hs.fi/maailma/art-2000011347629.html
# [maailma] 52: https://www.hs.fi/maailma/art-2000011349708.html
# [maailma] 53: https://www.hs.fi/maailma/art-2000011345833.html
# [maailma] 54: https://www.hs.fi/maailma/art-2000011348635.html
# [maailma] 55: https://www.hs.fi/maailma/art-2000011358913.html
# [maailma] 56: https://www.hs.fi/maailma/art-2000011356886.html
# [maailma] 57: https://www.hs.fi/maailma/art-2000011354095.html
# [maailma] 58: https://www.hs.fi/maailma/art-2000011343165.html
# [maailma] 59: https://www.hs.fi/maailma/art-2000011358936.html
# [maailma] 60: https://www.hs.fi/maailma/art-2000011353195.html
# [maailma] 61: https://www.hs.fi/maailma/art-2000011350879.html
# [maailma] 62: https://www.hs.fi/maailma/art-2000011345797.html
# [maailma] 63: https://www.hs.fi/maailma/art-2000011349233.html
# [maailma] 64: https://www.hs.fi/maailma/art-2000011349770.html
# [maailma] 65: https://www.hs.fi/maailma/art-2000011347428.html
# [maailma] 66: https://www.hs.fi/maailma/art-2000011348565.html
# [maailma] 67: https://www.hs.fi/maailma/art-2000011344854.html
# [maailma] 68: https://www.hs.fi/maailma/art-2000011352437.html
# [maailma] 69: https://www.hs.fi/maailma/art-2000011345256.html
# [maailma] 70: https://www.hs.fi/maailma/art-2000011344800.html
# [maailma] 71: https://www.hs.fi/maailma/art-2000011354323.html
# [maailma] 72: https://www.hs.fi/maailma/art-2000011349354.html
# [maailma] 73: https://www.hs.fi/maailma/art-2000011347928.html
# [maailma] 74: https://www.hs.fi/maailma/art-2000011346337.html
# [maailma] 75: https://www.hs.fi/maailma/art-2000011352490.html
# [maailma] 76: https://www.hs.fi/maailma/art-2000011347765.html
# [maailma] 77: https://www.hs.fi/maailma/art-2000011342454.html
# [maailma] 78: https://www.hs.fi/maailma/art-2000011356376.html
# [maailma] 79: https://www.hs.fi/maailma/art-2000011356632.html
# [maailma] 80: https://www.hs.fi/maailma/art-2000011349479.html
# [maailma] 81: https://www.hs.fi/maailma/art-2000011347747.html
# [maailma] 82: https://www.hs.fi/maailma/art-2000011359044.html
# [maailma] 83: https://www.hs.fi/maailma/art-2000011351968.html
# [maailma] 84: https://www.hs.fi/maailma/art-2000011347781.html
# [maailma] 85: https://www.hs.fi/maailma/art-2000011354232.html
# [maailma] 86: https://www.hs.fi/maailma/art-2000011354281.html
# [maailma] 87: https://www.hs.fi/maailma/art-2000011353564.html
# [maailma] 88: https://www.hs.fi/maailma/art-2000011346143.html
# [maailma] 89: https://www.hs.fi/maailma/art-2000011348804.html
# Сохранено 89 статей из 'maailma'
#
# Рубрика: paakirjoitukset
# [paakirjoitukset] 1: https://www.hs.fi/paakirjoitukset/art-2000011323711.html
#
# Предпросмотр:
# ================================================================================
# Pääkirjoitus|Ensimmäinen uudistettu yleisesikuntaupseerikurssi aloitti opiskelunsa Maanpuolustuskorkeakoulussa.
# Suomen ylimpien upseerien koulutuksessa siirryttiin juhannuksen jälkeen uuteen Nato-aikaan. Viitisenkymmentä kunnianhimoista upseeria aloitti opintonsa yleisesikuntaupseerikurssilla, joka poikkeaa monin tavoin aikaisemmista kursseista.
# Yleisesikuntaupseerikurssin suorittaminen on välttämätöntä kaikille sotilaille, jotka haluavat Puolustusvoimien tai Naton ylimpiin tehtäviin. Kurssille ei ylene automaattisesti, vaan sinne on oma karsiva valintamenettelynsä.
# Suomen liittyminen Natoon aiheutti sen, että vanhaa ja perinteistä kurssia on pitänyt uudistaa. Tavoitteena on, että tulevilla eversteillä ja kenraaleilla on kurssin jälkeen entistä paremmat edellytykset toimia Nato-esikuntien korkeimmissa tehtävissä.
# Yleisesikuntaupseerikurssin uudistaminen liittyy käynnissä olevaan laajempaan upseerikoulutuksen kehittämiseen. Koulutuksen laatua on Nato-jäsenyyden myötä pitänyt parantaa kaikilla tutkinto- ja kurssitasoilla. Suomalaisten upseerien pitää jatkossa pystyä sota-aikana suoriutumaan entistä vaativammista tehtävistä. Yleisesikuntaupseerien on kyettävä puolustushaara- ja pääesikuntatason tehtäviin. Lisäksi heillä pitää olla kyky toimia Naton operatiivisen tason tehtävissä esimerkiksi Norfolkin ja Brunssumin esikunnissa.
# Natolla ei ole sinänsä vaatimuksia eri maiden upseerikoulutukselle. Jokaisella tutkinto- ja kurssitasolla eri maista tulevien upseerien pitää kuitenkin os
# ================================================================================
# [paakirjoitukset] 2: https://www.hs.fi/paakirjoitukset/art-2000011352045.html
# [paakirjoitukset] 3: https://www.hs.fi/paakirjoitukset/art-2000011311039.html
# [paakirjoitukset] 4: https://www.hs.fi/paakirjoitukset/art-2000011316930.html
# [paakirjoitukset] 5: https://www.hs.fi/paakirjoitukset/art-2000011319541.html
# [paakirjoitukset] 6: https://www.hs.fi/paakirjoitukset/art-2000011342684.html
# [paakirjoitukset] 7: https://www.hs.fi/paakirjoitukset/art-2000011347813.html
# [paakirjoitukset] 8: https://www.hs.fi/paakirjoitukset/art-2000011310634.html
# [paakirjoitukset] 9: https://www.hs.fi/paakirjoitukset/art-2000011350154.html
# [paakirjoitukset] 10: https://www.hs.fi/paakirjoitukset/art-2000011338471.html
# [paakirjoitukset] 11: https://www.hs.fi/paakirjoitukset/art-2000011304859.html
# [paakirjoitukset] 12: https://www.hs.fi/paakirjoitukset/art-2000011353060.html
# [paakirjoitukset] 13: https://www.hs.fi/paakirjoitukset/art-2000011329027.html
# [paakirjoitukset] 14: https://www.hs.fi/paakirjoitukset/art-2000011346775.html
# [paakirjoitukset] 15: https://www.hs.fi/paakirjoitukset/art-2000011312919.html
# [paakirjoitukset] 16: https://www.hs.fi/paakirjoitukset/art-2000011327629.html
# [paakirjoitukset] 17: https://www.hs.fi/paakirjoitukset/art-2000011315894.html
# [paakirjoitukset] 18: https://www.hs.fi/paakirjoitukset/art-2000011339519.html
# [paakirjoitukset] 19: https://www.hs.fi/paakirjoitukset/art-2000011335416.html
# [paakirjoitukset] 20: https://www.hs.fi/paakirjoitukset/art-2000011310802.html
# [paakirjoitukset] 21: https://www.hs.fi/paakirjoitukset/art-2000011339603.html
# [paakirjoitukset] 22: https://www.hs.fi/paakirjoitukset/art-2000011316972.html
# [paakirjoitukset] 23: https://www.hs.fi/paakirjoitukset/art-2000011306713.html
# [paakirjoitukset] 24: https://www.hs.fi/paakirjoitukset/art-2000011352881.html
# [paakirjoitukset] 25: https://www.hs.fi/paakirjoitukset/art-2000011336376.html
# [paakirjoitukset] 26: https://www.hs.fi/paakirjoitukset/art-2000011327677.html
# [paakirjoitukset] 27: https://www.hs.fi/paakirjoitukset/art-2000011342647.html
# [paakirjoitukset] 28: https://www.hs.fi/paakirjoitukset/art-2000011315938.html
# [paakirjoitukset] 29: https://www.hs.fi/paakirjoitukset/art-2000011304916.html
# [paakirjoitukset] 30: https://www.hs.fi/paakirjoitukset/art-2000011332374.html
# [paakirjoitukset] 31: https://www.hs.fi/paakirjoitukset/art-2000011346082.html
# [paakirjoitukset] 32: https://www.hs.fi/paakirjoitukset/art-2000011320897.html
# [paakirjoitukset] 33: https://www.hs.fi/paakirjoitukset/art-2000011275014.html
# [paakirjoitukset] 34: https://www.hs.fi/paakirjoitukset/art-2000011306511.html
# [paakirjoitukset] 35: https://www.hs.fi/paakirjoitukset/art-2000011332439.html
# [paakirjoitukset] 36: https://www.hs.fi/paakirjoitukset/art-2000011329362.html
# [paakirjoitukset] 37: https://www.hs.fi/paakirjoitukset/art-2000011312866.html
# [paakirjoitukset] 38: https://www.hs.fi/paakirjoitukset/art-2000011345417.html
# [paakirjoitukset] 39: https://www.hs.fi/paakirjoitukset/art-2000011345947.html
# [paakirjoitukset] 40: https://www.hs.fi/paakirjoitukset/art-2000011324536.html
# [paakirjoitukset] 41: https://www.hs.fi/paakirjoitukset/art-2000011324755.html
# [paakirjoitukset] 42: https://www.hs.fi/paakirjoitukset/art-2000011304500.html
# [paakirjoitukset] 43: https://www.hs.fi/paakirjoitukset/art-2000011344352.html
# [paakirjoitukset] 44: https://www.hs.fi/paakirjoitukset/art-2000011343734.html
# [paakirjoitukset] 45: https://www.hs.fi/paakirjoitukset/art-2000011346884.html
# [paakirjoitukset] 46: https://www.hs.fi/paakirjoitukset/art-2000011294160.html
# [paakirjoitukset] 47: https://www.hs.fi/paakirjoitukset/art-2000011342834.html
# [paakirjoitukset] 48: https://www.hs.fi/paakirjoitukset/art-2000011309509.html
# [paakirjoitukset] 49: https://www.hs.fi/paakirjoitukset/art-2000011341348.html
# [paakirjoitukset] 50: https://www.hs.fi/paakirjoitukset/art-2000011322135.html
# [paakirjoitukset] 51: https://www.hs.fi/paakirjoitukset/art-2000011335948.html
# [paakirjoitukset] 52: https://www.hs.fi/paakirjoitukset/art-2000011319647.html
# [paakirjoitukset] 53: https://www.hs.fi/paakirjoitukset/art-2000011325964.html
# [paakirjoitukset] 54: https://www.hs.fi/paakirjoitukset/art-2000011319407.html
# [paakirjoitukset] 55: https://www.hs.fi/paakirjoitukset/art-2000011322183.html
# [paakirjoitukset] 56: https://www.hs.fi/paakirjoitukset/art-2000011350512.html
# [paakirjoitukset] 57: https://www.hs.fi/paakirjoitukset/art-2000011308083.html
# [paakirjoitukset] 58: https://www.hs.fi/paakirjoitukset/art-2000011307176.html
# [paakirjoitukset] 59: https://www.hs.fi/paakirjoitukset/art-2000011342792.html
# [paakirjoitukset] 60: https://www.hs.fi/paakirjoitukset/art-2000011323752.html
# [paakirjoitukset] 61: https://www.hs.fi/paakirjoitukset/art-2000011310309.html
# [paakirjoitukset] 62: https://www.hs.fi/paakirjoitukset/art-2000011317016.html
# [paakirjoitukset] 63: https://www.hs.fi/paakirjoitukset/art-2000011304178.html
# [paakirjoitukset] 64: https://www.hs.fi/paakirjoitukset/art-2000011313540.html
# [paakirjoitukset] 65: https://www.hs.fi/paakirjoitukset/art-2000011356533.html
# [paakirjoitukset] 66: https://www.hs.fi/paakirjoitukset/art-2000011348277.html
# [paakirjoitukset] 67: https://www.hs.fi/paakirjoitukset/art-2000011337724.html
# [paakirjoitukset] 68: https://www.hs.fi/paakirjoitukset/art-2000011309750.html
# [paakirjoitukset] 69: https://www.hs.fi/paakirjoitukset/art-2000011303517.html
# [paakirjoitukset] 70: https://www.hs.fi/paakirjoitukset/art-2000011312476.html
# [paakirjoitukset] 71: https://www.hs.fi/paakirjoitukset/art-2000011353639.html
# [paakirjoitukset] 72: https://www.hs.fi/paakirjoitukset/art-2000011311239.html
# [paakirjoitukset] 73: https://www.hs.fi/paakirjoitukset/art-2000011350247.html
# [paakirjoitukset] 74: https://www.hs.fi/paakirjoitukset/art-2000011338654.html
# [paakirjoitukset] 75: https://www.hs.fi/paakirjoitukset/art-2000011316598.html
# [paakirjoitukset] 76: https://www.hs.fi/paakirjoitukset/art-2000011314710.html
# [paakirjoitukset] 77: https://www.hs.fi/paakirjoitukset/art-2000011323044.html
# [paakirjoitukset] 78: https://www.hs.fi/paakirjoitukset/art-2000011327324.html
# [paakirjoitukset] 79: https://www.hs.fi/paakirjoitukset/art-2000011275924.html
# [paakirjoitukset] 80: https://www.hs.fi/paakirjoitukset/art-2000011324349.html
# [paakirjoitukset] 81: https://www.hs.fi/paakirjoitukset/art-2000011343175.html
# [paakirjoitukset] 82: https://www.hs.fi/paakirjoitukset/art-2000011332843.html
# [paakirjoitukset] 83: https://www.hs.fi/paakirjoitukset/art-2000011335723.html
# [paakirjoitukset] 84: https://www.hs.fi/paakirjoitukset/art-2000011316875.html
# [paakirjoitukset] 85: https://www.hs.fi/paakirjoitukset/art-2000011356777.html
# [paakirjoitukset] 86: https://www.hs.fi/paakirjoitukset/art-2000011313508.html
# [paakirjoitukset] 87: https://www.hs.fi/paakirjoitukset/art-2000011335518.html
# [paakirjoitukset] 88: https://www.hs.fi/paakirjoitukset/art-2000011318252.html
# [paakirjoitukset] 89: https://www.hs.fi/paakirjoitukset/art-2000011341172.html
# [paakirjoitukset] 90: https://www.hs.fi/paakirjoitukset/art-2000011356665.html
# [paakirjoitukset] 91: https://www.hs.fi/paakirjoitukset/art-2000011317782.html
# [paakirjoitukset] 92: https://www.hs.fi/paakirjoitukset/art-2000011357836.html
# [paakirjoitukset] 93: https://www.hs.fi/paakirjoitukset/art-2000011357060.html
# [paakirjoitukset] 94: https://www.hs.fi/paakirjoitukset/art-2000011334702.html
# [paakirjoitukset] 95: https://www.hs.fi/paakirjoitukset/art-2000011333584.html
# [paakirjoitukset] 96: https://www.hs.fi/paakirjoitukset/art-2000011320637.html
# Сохранено 96 статей из 'paakirjoitukset'
#
# Рубрика: alueet
# [alueet] 1: https://www.hs.fi/alueet/art-2000011293673.html
#
# Предпросмотр:
# ================================================================================
# Työelämä|Juuri merkonomiksi valmistuneen Jace Hellénin mukaan nuorille voisi opettaa, että työssä eteen tulevaa luppoaikaa käytetään lisätyön tekemiseen. Asiantuntijan mukaan iso osa nuorten työelämähaasteista liittyykin itsensä johtamiseen ja arjen hallintaan.
# Turkulainen Jace Hellén ajattelee, että hänen pitää tulevaisuudessa työelämässä uskaltaa rohkeammin kysyä mahdollisuuksista oppia uutta.Kuva:Sami Kilpiö / HS
# Nuorten siirtymä koulusta työelämään on nykyään pitkä ja monivaiheinen prosessi, kertoo Suomen työnohjaajat ry:n puheenjohtaja Riitta Malkamäki.
# Työltä haetaan entistä enemmän merkityksellisyyttä, mutta osalla nuorista on haasteita arjen hallinnassa, mikä näkyy vaikeuksina myös työpaikoilla.
# Malkamäen mukaan koulujen ja työpaikkojen tulisi panostaa siihen, että nuorilla on valmiudet onnistua työssään.
# Nuortensopeutuminen työelämään on yhä vaikeampaa.
# Näin sanoo Suomen työnohjaajat ry:n puheenjohtajaRiitta Malkamäki, joka tiivistää nuorten työelämähaasteet kahteen ääripäähän.
# Toisessa päässä nuoret kamppailevat arvojen kanssa. Työltä haetaan entistä enemmän merkityksellisyyttä.
# ”Tämä on uusi ilmiö”, Malkamäki kertoo.
# Toisessa ääripäässä nuoret kokevat ongelmia työelämässä, koska oma arjen hallinta on hataralla pohjalla.
# Siirtymä koulunpenkiltä työtuoliin onkin yhä useammin pitkä ja monivaiheinen prosessi.
# ”Nuorelta edellytetään kykyä johtaa itseään, toimia yhteistyössä, oppia jatkuvasti ja sietää epävarmuutta”, Malkamäki listaa.
# Hänen mukaansa niin kouluissa kuin t
# ================================================================================
# [alueet] 2: https://www.hs.fi/alueet/art-2000011271719.html
# [alueet] 3: https://www.hs.fi/alueet/art-2000011323004.html
# [alueet] 4: https://www.hs.fi/alueet/art-2000011259417.html
# [alueet] 5: https://www.hs.fi/alueet/art-2000011248530.html
# [alueet] 6: https://www.hs.fi/alueet/art-2000011254987.html
# [alueet] 7: https://www.hs.fi/alueet/art-2000011079172.html
# [alueet] 8: https://www.hs.fi/alueet/art-2000011222938.html
# [alueet] 9: https://www.hs.fi/alueet/art-2000011141805.html
# [alueet] 10: https://www.hs.fi/alueet/art-2000011342531.html
# [alueet] 11: https://www.hs.fi/alueet/art-2000011261597.html
# [alueet] 12: https://www.hs.fi/alueet/art-2000011324528.html
# [alueet] 13: https://www.hs.fi/alueet/art-2000011321075.html
# [alueet] 14: https://www.hs.fi/alueet/art-2000011300022.html
# [alueet] 15: https://www.hs.fi/alueet/art-2000011344982.html
# [alueet] 16: https://www.hs.fi/alueet/art-2000011273926.html
# [alueet] 17: https://www.hs.fi/alueet/art-2000011265117.html
# [alueet] 18: https://www.hs.fi/alueet/art-2000011249090.html
# [alueet] 19: https://www.hs.fi/alueet/art-2000011234099.html
# [alueet] 20: https://www.hs.fi/alueet/art-2000011245877.html
# [alueet] 21: https://www.hs.fi/alueet/art-2000011319707.html
# [alueet] 22: https://www.hs.fi/alueet/art-2000011296168.html
# [alueet] 23: https://www.hs.fi/alueet/art-2000011184630.html
# [alueet] 24: https://www.hs.fi/alueet/art-2000011227031.html
# [alueet] 25: https://www.hs.fi/alueet/art-2000011280635.html
# [alueet] 26: https://www.hs.fi/alueet/art-2000011176666.html
# [alueet] 27: https://www.hs.fi/alueet/art-2000011265574.html
# [alueet] 28: https://www.hs.fi/alueet/art-2000011232854.html
# [alueet] 29: https://www.hs.fi/alueet/art-2000011288132.html
# [alueet] 30: https://www.hs.fi/alueet/art-2000011251691.html
# [alueet] 31: https://www.hs.fi/alueet/art-2000011332853.html
# [alueet] 32: https://www.hs.fi/alueet/art-2000011278713.html
# [alueet] 33: https://www.hs.fi/alueet/art-2000011326268.html
# [alueet] 34: https://www.hs.fi/alueet/art-2000011332498.html
# [alueet] 35: https://www.hs.fi/alueet/art-2000011229798.html
# [alueet] 36: https://www.hs.fi/alueet/art-2000011240651.html
# [alueet] 37: https://www.hs.fi/alueet/art-2000011264102.html
# [alueet] 38: https://www.hs.fi/alueet/art-2000011242778.html
# [alueet] 39: https://www.hs.fi/alueet/art-2000011337347.html
# [alueet] 40: https://www.hs.fi/alueet/art-2000011354986.html
# [alueet] 41: https://www.hs.fi/alueet/art-2000011295139.html
# [alueet] 42: https://www.hs.fi/alueet/art-2000011306235.html
# [alueet] 43: https://www.hs.fi/alueet/art-2000011237958.html
# [alueet] 44: https://www.hs.fi/alueet/art-2000011332375.html
# [alueet] 45: https://www.hs.fi/alueet/art-2000011277192.html
# [alueet] 46: https://www.hs.fi/alueet/art-2000011270889.html
# Сохранено 46 статей из 'alueet'
#
# Рубрика: suomi
# [suomi] 1: https://www.hs.fi/suomi/art-2000011357677.html
#
# Предпросмотр:
# ================================================================================
# Suomi|Moderni pyhiinvaeltaminen voi olla eräänlaista löytöretkeilyä tai seikkailua historiallisilla reiteillä.
# Pyhiinvaeltaja saapuu päätepisteelleen Pyhän Laurin kirkolle Vantaalla.Kuva:Saara Peltola / Lehtikuva
# Monisuomalainen tuntee legendan talonpoika Lallista, jonka kerrotaan surmanneen piispa Henrikin Köyliönjärven jäällä 1100-luvulla.
# Harvempi ehkä tietää, että Köyliönjärvelle vie nykyisin Suomen vanhin pyhiinvaellusreitti Pyhän Henrikin tie, joka kulkee Turun ja Kokemäen välillä.
# Pyhiinvaelluksen suosio Suomessa kasvaa koko ajan, kertoo pyhiinvaellustoiminnan projektipäällikköAnnastiina PapinahoTurun arkkihiippakunnan tuomiokapitulista STT:lle.
# Korona-aikainenlähiluontoretkeilyn suosiopiikki heijastui myös pyhiinvaeltamiseen. Turun kaupunki ja Suomen evankelis-luterilainen kirkko avasivat vuonna 2021 Suomen ensimmäisen pyhiinvaelluskeskuksen Turun tuomiokirkolle koordinoimaan Suomen pyhiinvaellusreittejä. Moni historiallinen pyhiinvaellusreitti risteää juuri Turkuun.
# Suomen vanhimmat pyhiinvaellusreitit juontavat juurensa keskiajalle, joka oli pyhiinvaeltamisen kulta-aikaa, Papinaho kertoo. Alue kuului tuolloin Ruotsiin, joka oli katolinen maa.
# Reformaation saapuessa Suomeen pyhiinvaellus oli yksi niistä katolisista perinteistä, joita karsittiin tietoisesti pois.
# Nyt pyhiinvaeltamista on tarkoituksella elvytetty myös luterilaisessa perinteessä, mistä esimerkkinä on Turun pyhiinvaelluskeskus.
# Papinaho kertoo, että perustamisensa jälkeen keskus sai paljon positiivista,
# ================================================================================
# [suomi] 2: https://www.hs.fi/suomi/art-2000011348839.html
# [suomi] 3: https://www.hs.fi/suomi/art-2000011348744.html
# [suomi] 4: https://www.hs.fi/suomi/art-2000011352053.html
# [suomi] 5: https://www.hs.fi/suomi/art-2000011350731.html
# [suomi] 6: https://www.hs.fi/suomi/art-2000011355383.html
# [suomi] 7: https://www.hs.fi/suomi/art-2000011351205.html
# [suomi] 8: https://www.hs.fi/suomi/art-2000011351003.html
# [suomi] 9: https://www.hs.fi/suomi/art-2000011348346.html
# [suomi] 10: https://www.hs.fi/suomi/art-2000011338383.html
# [suomi] 11: https://www.hs.fi/suomi/art-2000011277929.html
# [suomi] 12: https://www.hs.fi/suomi/art-2000011347933.html
# [suomi] 13: https://www.hs.fi/suomi/art-2000011351939.html
# [suomi] 14: https://www.hs.fi/suomi/art-2000011345739.html
# [suomi] 15: https://www.hs.fi/suomi/art-2000011348276.html
# [suomi] 16: https://www.hs.fi/suomi/art-2000011359886.html
# [suomi] 17: https://www.hs.fi/suomi/art-2000011355676.html
# [suomi] 18: https://www.hs.fi/suomi/art-2000011348724.html
# [suomi] 19: https://www.hs.fi/suomi/art-2000011347875.html
# [suomi] 20: https://www.hs.fi/suomi/art-2000011355120.html
# [suomi] 21: https://www.hs.fi/suomi/art-2000011358349.html
# [suomi] 22: https://www.hs.fi/suomi/art-2000011352536.html
# [suomi] 23: https://www.hs.fi/suomi/art-2000011343087.html
# [suomi] 24: https://www.hs.fi/suomi/art-2000011359245.html
# [suomi] 25: https://www.hs.fi/suomi/art-2000011353551.html
# [suomi] 26: https://www.hs.fi/suomi/art-2000011347836.html
# [suomi] 27: https://www.hs.fi/suomi/art-2000011351585.html
# [suomi] 28: https://www.hs.fi/suomi/art-2000011344749.html
# [suomi] 29: https://www.hs.fi/suomi/art-2000011356038.html
# [suomi] 30: https://www.hs.fi/suomi/art-2000011342323.html
# [suomi] 31: https://www.hs.fi/suomi/art-2000011343422.html
# [suomi] 32: https://www.hs.fi/suomi/art-2000011344496.html
# [suomi] 33: https://www.hs.fi/suomi/art-2000011360567.html
# [suomi] 34: https://www.hs.fi/suomi/art-2000011348407.html
# [suomi] 35: https://www.hs.fi/suomi/art-2000011352043.html
# [suomi] 36: https://www.hs.fi/suomi/art-2000011345167.html
# [suomi] 37: https://www.hs.fi/suomi/art-2000011348114.html
# [suomi] 38: https://www.hs.fi/suomi/art-2000011343898.html
# [suomi] 39: https://www.hs.fi/suomi/art-2000011355628.html
# [suomi] 40: https://www.hs.fi/suomi/art-2000011349753.html
# [suomi] 41: https://www.hs.fi/suomi/art-2000011349681.html
# [suomi] 42: https://www.hs.fi/suomi/art-2000011356568.html
# [suomi] 43: https://www.hs.fi/suomi/art-2000011349894.html
# [suomi] 44: https://www.hs.fi/suomi/art-2000011348164.html
# [suomi] 45: https://www.hs.fi/suomi/art-2000011345222.html
# [suomi] 46: https://www.hs.fi/suomi/art-2000011344305.html
# [suomi] 47: https://www.hs.fi/suomi/art-2000011357932.html
# [suomi] 48: https://www.hs.fi/suomi/art-2000011354715.html
# [suomi] 49: https://www.hs.fi/suomi/art-2000011348368.html
# [suomi] 50: https://www.hs.fi/suomi/art-2000011351702.html
# [suomi] 51: https://www.hs.fi/suomi/art-2000011348978.html
# [suomi] 52: https://www.hs.fi/suomi/art-2000011344843.html
# [suomi] 53: https://www.hs.fi/suomi/art-2000011352235.html
# [suomi] 54: https://www.hs.fi/suomi/art-2000011356265.html
# [suomi] 55: https://www.hs.fi/suomi/art-2000011344747.html
# [suomi] 56: https://www.hs.fi/suomi/art-2000011358921.html
# [suomi] 57: https://www.hs.fi/suomi/art-2000011347275.html
# [suomi] 58: https://www.hs.fi/suomi/art-2000011356952.html
# [suomi] 59: https://www.hs.fi/suomi/art-2000011354019.html
# [suomi] 60: https://www.hs.fi/suomi/art-2000011347912.html
# [suomi] 61: https://www.hs.fi/suomi/art-2000011346536.html
# [suomi] 62: https://www.hs.fi/suomi/art-2000011360553.html
# [suomi] 63: https://www.hs.fi/suomi/art-2000011356818.html
# [suomi] 64: https://www.hs.fi/suomi/art-2000011345022.html
# [suomi] 65: https://www.hs.fi/suomi/art-2000011346182.html
# [suomi] 66: https://www.hs.fi/suomi/art-2000011345104.html
# [suomi] 67: https://www.hs.fi/suomi/art-2000011349138.html
# [suomi] 68: https://www.hs.fi/suomi/art-2000011351751.html
# [suomi] 69: https://www.hs.fi/suomi/art-2000011353207.html
# [suomi] 70: https://www.hs.fi/suomi/art-2000011345168.html
# [suomi] 71: https://www.hs.fi/suomi/art-2000011354864.html
# [suomi] 72: https://www.hs.fi/suomi/art-2000011351933.html
# [suomi] 73: https://www.hs.fi/suomi/art-2000011325441.html
# [suomi] 74: https://www.hs.fi/suomi/art-2000011347850.html
# [suomi] 75: https://www.hs.fi/suomi/art-2000011342456.html
# [suomi] 76: https://www.hs.fi/suomi/art-2000011346753.html
# [suomi] 77: https://www.hs.fi/suomi/art-2000011343645.html
# [suomi] 78: https://www.hs.fi/suomi/art-2000011345840.html
# [suomi] 79: https://www.hs.fi/suomi/art-2000011346205.html
# [suomi] 80: https://www.hs.fi/suomi/art-2000011353290.html
# [suomi] 81: https://www.hs.fi/suomi/art-2000011359076.html
# [suomi] 82: https://www.hs.fi/suomi/art-2000011345839.html
# [suomi] 83: https://www.hs.fi/suomi/art-2000011342922.html
# Сохранено 83 статей из 'suomi'
#
# Рубрика: politiikka
# [politiikka] 1: https://www.hs.fi/politiikka/art-2000011354744.html
#
# Предпросмотр:
# ================================================================================
# Graffitit|Purra kertoo vieneensä tiedon graffitista eteenpäin.
# Graffiti sijaitsee Suvilahden graffitiseinässä.Kuva:Kari Pullinen
# HelsinginSuvilahdessa sijaitsevaan graffitiseinään on maalattu kuvat pääministeriPetteri Orposta(kok) ja valtiovarainministeriRiikka Purrasta(ps).
# Kuvat jäljittelevät lännenelokuvista tuttuja etsintäkuulutusjulisteita. Niissä lukee, että Orpo ja Purra halutaan ”elävänä tai kuolleena”. Graffitiseinää hallinnoi energiayhtiö Helen.
# Graffitista kertoi torstaina ensimmäisenäIltalehti.
# Purra kertoo vieneensä tiedon graffitista eteenpäin.
# ”Kaikki väkivallalla, tappamisella ynnä muulla uhkaamiset menevät kohdallani valtioneuvoston kautta eteenpäin selvitykseen”, Purra viestittää HS:lle.
# Pääministeri Orpo ei halunnut kommentoida asiaa.
# Purranmukaan uhkaavat viestit eivät ole harvinaisia.
# ”Uhkauksia tulee valitettavasti säännöllisesti, pääasiassa somen kautta. Motiivina lienee poliittisesti motivoitu viha.”
# Purraa esittävä graffiti maalattiin samaiseen graffitiseinään myösviime joulukuussa. Tuolloin Helen päätyi poistamaan graffitin.
# HS ei torstaina iltapäivästä tavoittanut Heleniä kommentoimaan, aikovatko he poistaa nyt ilmestyneet graffitit.
# Päivitetty klo 18.33: Lisätty tieto, että uutisesta kertoi ensimmäisenä Iltalehti.
# ================================================================================
# [politiikka] 2: https://www.hs.fi/politiikka/art-2000011344290.html
# [politiikka] 3: https://www.hs.fi/politiikka/art-2000011331024.html
# [politiikka] 4: https://www.hs.fi/politiikka/art-2000011353406.html
# [politiikka] 5: https://www.hs.fi/politiikka/art-2000011343204.html
# [politiikka] 6: https://www.hs.fi/politiikka/art-2000011342517.html
# [politiikka] 7: https://www.hs.fi/politiikka/art-2000011333003.html
# [politiikka] 8: https://www.hs.fi/politiikka/art-2000011328005.html
# [politiikka] 9: https://www.hs.fi/politiikka/art-2000011352562.html
# [politiikka] 10: https://www.hs.fi/politiikka/art-2000011351572.html
# [politiikka] 11: https://www.hs.fi/politiikka/art-2000011347861.html
# [politiikka] 12: https://www.hs.fi/politiikka/art-2000011331260.html
# [politiikka] 13: https://www.hs.fi/politiikka/art-2000011347414.html
# [politiikka] 14: https://www.hs.fi/politiikka/art-2000011326254.html
# [politiikka] 15: https://www.hs.fi/politiikka/art-2000011335658.html
# [politiikka] 16: https://www.hs.fi/politiikka/art-2000011359486.html
# [politiikka] 17: https://www.hs.fi/politiikka/art-2000011338376.html
# [politiikka] 18: https://www.hs.fi/politiikka/art-2000011339700.html
# [politiikka] 19: https://www.hs.fi/politiikka/art-2000011341838.html
# [politiikka] 20: https://www.hs.fi/politiikka/art-2000011338593.html
# [politiikka] 21: https://www.hs.fi/politiikka/art-2000011357262.html
# [politiikka] 22: https://www.hs.fi/politiikka/art-2000011328213.html
# [politiikka] 23: https://www.hs.fi/politiikka/art-2000011348936.html
# [politiikka] 24: https://www.hs.fi/politiikka/art-2000011341827.html
# [politiikka] 25: https://www.hs.fi/politiikka/art-2000011341837.html
# [politiikka] 26: https://www.hs.fi/politiikka/art-2000011335661.html
# [politiikka] 27: https://www.hs.fi/politiikka/art-2000011333528.html
# [politiikka] 28: https://www.hs.fi/politiikka/art-2000011345494.html
# [politiikka] 29: https://www.hs.fi/politiikka/art-2000011347586.html
# [politiikka] 30: https://www.hs.fi/politiikka/art-2000011333353.html
# [politiikka] 31: https://www.hs.fi/politiikka/art-2000011332135.html
# [politiikka] 32: https://www.hs.fi/politiikka/art-2000011341570.html
# [politiikka] 33: https://www.hs.fi/politiikka/art-2000011353568.html
# [politiikka] 34: https://www.hs.fi/politiikka/art-2000011353565.html
# [politiikka] 35: https://www.hs.fi/politiikka/art-2000011345208.html
# [politiikka] 36: https://www.hs.fi/politiikka/art-2000011351190.html
# [politiikka] 37: https://www.hs.fi/politiikka/art-2000011352518.html
# [politiikka] 38: https://www.hs.fi/politiikka/art-2000011341943.html
# [politiikka] 39: https://www.hs.fi/politiikka/art-2000011333436.html
# [politiikka] 40: https://www.hs.fi/politiikka/art-2000011343881.html
# [politiikka] 41: https://www.hs.fi/politiikka/art-2000011334665.html
# [politiikka] 42: https://www.hs.fi/politiikka/art-2000011344165.html
# [politiikka] 43: https://www.hs.fi/politiikka/art-2000011360031.html
# [politiikka] 44: https://www.hs.fi/politiikka/art-2000011353764.html
# [politiikka] 45: https://www.hs.fi/politiikka/art-2000011347133.html
# [politiikka] 46: https://www.hs.fi/politiikka/art-2000011332561.html
# [politiikka] 47: https://www.hs.fi/politiikka/art-2000011348159.html
# [politiikka] 48: https://www.hs.fi/politiikka/art-2000011345693.html
# [politiikka] 49: https://www.hs.fi/politiikka/art-2000011334392.html
# [politiikka] 50: https://www.hs.fi/politiikka/art-2000011326585.html
# [politiikka] 51: https://www.hs.fi/politiikka/art-2000011351213.html
# [politiikka] 52: https://www.hs.fi/politiikka/art-2000011358243.html
# [politiikka] 53: https://www.hs.fi/politiikka/art-2000011332793.html
# [politiikka] 54: https://www.hs.fi/politiikka/art-2000011331282.html
# [politiikka] 55: https://www.hs.fi/politiikka/art-2000011350680.html
# [politiikka] 56: https://www.hs.fi/politiikka/art-2000011325336.html
# [politiikka] 57: https://www.hs.fi/politiikka/art-2000011343067.html
# [politiikka] 58: https://www.hs.fi/politiikka/art-2000011339619.html
# [politiikka] 59: https://www.hs.fi/politiikka/art-2000011328048.html
# [politiikka] 60: https://www.hs.fi/politiikka/art-2000011342276.html
# [politiikka] 61: https://www.hs.fi/politiikka/art-2000011335517.html
# [politiikka] 62: https://www.hs.fi/politiikka/art-2000011347381.html
# [politiikka] 63: https://www.hs.fi/politiikka/art-2000011353808.html
# [politiikka] 64: https://www.hs.fi/politiikka/art-2000011338706.html
# [politiikka] 65: https://www.hs.fi/politiikka/art-2000011344163.html
# [politiikka] 66: https://www.hs.fi/politiikka/art-2000011356204.html
# [politiikka] 67: https://www.hs.fi/politiikka/art-2000011343831.html
# [politiikka] 68: https://www.hs.fi/politiikka/art-2000011343030.html
# [politiikka] 69: https://www.hs.fi/politiikka/art-2000011347534.html
# [politiikka] 70: https://www.hs.fi/politiikka/art-2000011322990.html
# [politiikka] 71: https://www.hs.fi/politiikka/art-2000011312191.html
# [politiikka] 72: https://www.hs.fi/politiikka/art-2000011359808.html
# [politiikka] 73: https://www.hs.fi/politiikka/art-2000011356557.html
# [politiikka] 74: https://www.hs.fi/politiikka/art-2000011328416.html
# [politiikka] 75: https://www.hs.fi/politiikka/art-2000011358852.html
# [politiikka] 76: https://www.hs.fi/politiikka/art-2000011359828.html
# [politiikka] 77: https://www.hs.fi/politiikka/art-2000011344459.html
# [politiikka] 78: https://www.hs.fi/politiikka/art-2000011334127.html
# [politiikka] 79: https://www.hs.fi/politiikka/art-2000011324923.html
# Сохранено 79 статей из 'politiikka'
#
# Рубрика: helsinki
# [helsinki] 1: https://www.hs.fi/helsinki/art-2000011317383.html
#
# Предпросмотр:
# ================================================================================
# Helsinki|HS:n haastattelemat asukkaat ovat olleet yllättyneitä vastikkeiden rajusta noususta lyhyessä ajassa.
# Oulunkylän Patolassa 98,5 neliön asunnon vastike on noussut vuosien 2022 ja 2025 välillä runsaasti. Laskun yksilöivät tiedot on peitetty HS:n toimituksessa.Kuva:Haso-asukkaan vastikelaskut
# Helsingin kaupungin asumisoikeusyhtiö Haso on nostanut vastikkeitaan huomattavasti viime vuosina.
# Hason toimitusjohtaja Harri Palviainen kertoo huonon taloustilanteen syyksi kohonneet kustannukset, korot ja valtion korkotuen pienenemisen.
# Ensi vuodelle on luvassa keskimäärin kahdeksan prosentin korotus vastikkeisiin yhtiön talouden vakauttamiseksi.
# Helsinginkaupungin asumisoikeusyhtiö Haso on nostanut vastikkeitaan runsaasti viime vuosina, ja useille asukkaille korotukset ovat tulleet yllätyksenä.
# Ainakin Verkkosaaressa sijaitsevan Haso-kerrostalo Haavin vastikkeet ovat nousseet vuosien 2021–2025 aikana jopa noin puolet korkeammiksi.
# Verkkosaaren Haavin asukkaanEvgeni Semenovinmukaan talossa asuu ihmisiä, jotka ovat Haso-asukkaiksi muuttaessaan kaivanneet nimenomaan kohtuuhintaista asumista.
# ”Kun naapureiden kanssa olen jutellut, niin aika monella alkaa olla maksukyvyn rajoilla, kun näitä korkeita korotuksia on tullut vuosittain”, hän sanoo.
# Semenov toimii Verkkosaaren Haavin asukastoimikunnan puheenjohtajana sekä Hason yhteistyöelimen jäsenenä.
# Haso on Helsingin kaupungin kokonaan omistama yhtiö, joka tuottaa kohtuuhintaisia asumisoikeusasuntoja niin kutsutulla omakustannus­periaat
# ================================================================================
# [helsinki] 2: https://www.hs.fi/helsinki/art-2000011343913.html
# [helsinki] 3: https://www.hs.fi/helsinki/art-2000011317434.html
# [helsinki] 4: https://www.hs.fi/helsinki/art-2000011325090.html
# [helsinki] 5: https://www.hs.fi/helsinki/art-2000011303316.html
# [helsinki] 6: https://www.hs.fi/helsinki/art-2000011342958.html
# [helsinki] 7: https://www.hs.fi/helsinki/art-2000011347299.html
# [helsinki] 8: https://www.hs.fi/helsinki/art-2000011340990.html
# [helsinki] 9: https://www.hs.fi/helsinki/art-2000011332476.html
# [helsinki] 10: https://www.hs.fi/helsinki/art-2000011349035.html
# [helsinki] 11: https://www.hs.fi/helsinki/art-2000011344992.html
# [helsinki] 12: https://www.hs.fi/helsinki/art-2000011335679.html
# [helsinki] 13: https://www.hs.fi/helsinki/art-2000011330947.html
# [helsinki] 14: https://www.hs.fi/helsinki/art-2000011354597.html
# [helsinki] 15: https://www.hs.fi/helsinki/art-2000011352396.html
# [helsinki] 16: https://www.hs.fi/helsinki/art-2000011337103.html
# [helsinki] 17: https://www.hs.fi/helsinki/art-2000011320596.html
# [helsinki] 18: https://www.hs.fi/helsinki/art-2000011357341.html
# [helsinki] 19: https://www.hs.fi/helsinki/art-2000011352163.html
# [helsinki] 20: https://www.hs.fi/helsinki/art-2000011352671.html
# [helsinki] 21: https://www.hs.fi/helsinki/art-2000011355348.html
# [helsinki] 22: https://www.hs.fi/helsinki/art-2000011334701.html
# [helsinki] 23: https://www.hs.fi/helsinki/art-2000011358207.html
# [helsinki] 24: https://www.hs.fi/helsinki/art-2000011317398.html
# [helsinki] 25: https://www.hs.fi/helsinki/art-2000011339151.html
# [helsinki] 26: https://www.hs.fi/helsinki/art-2000011331611.html
# [helsinki] 27: https://www.hs.fi/helsinki/art-2000011319147.html
# [helsinki] 28: https://www.hs.fi/helsinki/art-2000011339690.html
# [helsinki] 29: https://www.hs.fi/helsinki/art-2000011319281.html
# [helsinki] 30: https://www.hs.fi/helsinki/art-2000011332060.html
# [helsinki] 31: https://www.hs.fi/helsinki/art-2000011321871.html
# [helsinki] 32: https://www.hs.fi/helsinki/art-2000011310415.html
# [helsinki] 33: https://www.hs.fi/helsinki/art-2000011349876.html
# [helsinki] 34: https://www.hs.fi/helsinki/art-2000011338424.html
# [helsinki] 35: https://www.hs.fi/helsinki/art-2000011319500.html
# [helsinki] 36: https://www.hs.fi/helsinki/art-2000011337115.html
# [helsinki] 37: https://www.hs.fi/helsinki/art-2000011351998.html
# [helsinki] 38: https://www.hs.fi/helsinki/art-2000011331383.html
# [helsinki] 39: https://www.hs.fi/helsinki/art-2000011324842.html
# [helsinki] 40: https://www.hs.fi/helsinki/art-2000011349133.html
# [helsinki] 41: https://www.hs.fi/helsinki/art-2000011321993.html
# [helsinki] 42: https://www.hs.fi/helsinki/art-2000011345140.html
# [helsinki] 43: https://www.hs.fi/helsinki/art-2000011347431.html
# [helsinki] 44: https://www.hs.fi/helsinki/art-2000011348704.html
# [helsinki] 45: https://www.hs.fi/helsinki/art-2000011332039.html
# [helsinki] 46: https://www.hs.fi/helsinki/art-2000011354679.html
# [helsinki] 47: https://www.hs.fi/helsinki/art-2000011351594.html
# [helsinki] 48: https://www.hs.fi/helsinki/art-2000011351414.html
# [helsinki] 49: https://www.hs.fi/helsinki/art-2000011350363.html
# [helsinki] 50: https://www.hs.fi/helsinki/art-2000011325049.html
# [helsinki] 51: https://www.hs.fi/helsinki/art-2000011328226.html
# [helsinki] 52: https://www.hs.fi/helsinki/art-2000011354077.html
# [helsinki] 53: https://www.hs.fi/helsinki/art-2000011337745.html
# [helsinki] 54: https://www.hs.fi/helsinki/art-2000011292323.html
# [helsinki] 55: https://www.hs.fi/helsinki/art-2000011313557.html
# [helsinki] 56: https://www.hs.fi/helsinki/art-2000011336351.html
# [helsinki] 57: https://www.hs.fi/helsinki/art-2000011337994.html
# [helsinki] 58: https://www.hs.fi/helsinki/art-2000011310998.html
# [helsinki] 59: https://www.hs.fi/helsinki/art-2000011356744.html
# [helsinki] 60: https://www.hs.fi/helsinki/art-2000011358609.html
# [helsinki] 61: https://www.hs.fi/helsinki/art-2000011349743.html
# [helsinki] 62: https://www.hs.fi/helsinki/art-2000011348849.html
# [helsinki] 63: https://www.hs.fi/helsinki/art-2000011345526.html
# [helsinki] 64: https://www.hs.fi/helsinki/art-2000011330031.html
# [helsinki] 65: https://www.hs.fi/helsinki/art-2000011348282.html
# [helsinki] 66: https://www.hs.fi/helsinki/art-2000011323374.html
# [helsinki] 67: https://www.hs.fi/helsinki/art-2000011323039.html
# [helsinki] 68: https://www.hs.fi/helsinki/art-2000011351181.html
# [helsinki] 69: https://www.hs.fi/helsinki/art-2000011336992.html
# [helsinki] 70: https://www.hs.fi/helsinki/art-2000011331964.html
# [helsinki] 71: https://www.hs.fi/helsinki/art-2000011323449.html
# [helsinki] 72: https://www.hs.fi/helsinki/art-2000011333934.html
# [helsinki] 73: https://www.hs.fi/helsinki/art-2000011330516.html
# [helsinki] 74: https://www.hs.fi/helsinki/art-2000011351163.html
# [helsinki] 75: https://www.hs.fi/helsinki/art-2000011334120.html
# [helsinki] 76: https://www.hs.fi/helsinki/art-2000011324681.html
# [helsinki] 77: https://www.hs.fi/helsinki/art-2000011341563.html
# [helsinki] 78: https://www.hs.fi/helsinki/art-2000011342447.html
# [helsinki] 79: https://www.hs.fi/helsinki/art-2000011317107.html
# [helsinki] 80: https://www.hs.fi/helsinki/art-2000011337414.html
# [helsinki] 81: https://www.hs.fi/helsinki/art-2000011324639.html
# [helsinki] 82: https://www.hs.fi/helsinki/art-2000011327144.html
# [helsinki] 83: https://www.hs.fi/helsinki/art-2000011330203.html
# Сохранено 83 статей из 'helsinki'
#
# Рубрика: mielipide
# [mielipide] 1: https://www.hs.fi/mielipide/art-2000011356208.html
#
# Предпросмотр:
# ================================================================================
# Lukijan mielipide|Jos janoan itsekkäästi ja ahnaasti rikkauksia, vaurautta ja onnea, minun tulisi puolustaa heikoimpia, koska tasa-arvoinen yhteiskunta luo tutkitusti vaurautta.
# Kirjoitus on Helsingin Sanomien lukijan mielipide.
# Olinpitkään ajatellut, että ahneus ja itsekkyys olisivat maailman pahuuden takana, mutta ymmärsin niiden olevankin ihmisen tärkeimpiä piirteitä. Niiden merkitys ymmärretään tavallisesti vain valitettavan väärin.
# Jos janoan itsekkäästi ja ahnaasti rikkauksia, vaurautta ja onnea, minun tulisi puolustaa heikoimpia, koska tasa-arvoinen yhteiskunta luo tutkitusti vaurautta varmemmin kuin epätasa-arvoinen. Nyt esimerkiksi vallassa olevien oikeistopuolueiden politiikka sekä Suomessa että Yhdysvalloissa johtaa todennäköisesti jokaisen köyhtymiseen, koska molemmissa kuritetaan ja rangaistaan köyhiä ja siirretään varallisuutta rikkaille.
# Oikeasti ahne ja itsekäs ihminen puolustaa kiihkeästi myös luontoa, koska kaikki rikkautemme on lopulta sen varassa, selviääkö eläinten ja kasvien lajisto monimuotoisena.
# Itsekkyys ja ahneus ovat arvokkaimpia hyveitämme, mutta vain jos osaamme katsoa ja ajatella riittävän syvällisesti. Muussa tapauksessa itsekkyys ja ahneus ovat vain tappavia ja tuhoavia voimia.
# Susa Tyrniluoto
# Tampere
# HS:n toimitus valitsee ja toimittaa mielipidekirjoitukset. Voit jättää mielipidekirjoituksen tai tutustua kirjoitusten periaatteisiin osoitteessawww.hs.fi/kirjoitamielipidekirjoitus/.
# ================================================================================
# [mielipide] 2: https://www.hs.fi/mielipide/art-2000011356390.html
# [mielipide] 3: https://www.hs.fi/mielipide/art-2000011341196.html
# [mielipide] 4: https://www.hs.fi/mielipide/art-2000011353906.html
# [mielipide] 5: https://www.hs.fi/mielipide/art-2000011357895.html
# [mielipide] 6: https://www.hs.fi/mielipide/art-2000011281004.html
# [mielipide] 7: https://www.hs.fi/mielipide/art-2000011329061.html
# [mielipide] 8: https://www.hs.fi/mielipide/art-2000011355300.html
# [mielipide] 9: https://www.hs.fi/mielipide/art-2000011343439.html
# [mielipide] 10: https://www.hs.fi/mielipide/art-2000011310528.html
# [mielipide] 11: https://www.hs.fi/mielipide/art-2000011335452.html
# [mielipide] 12: https://www.hs.fi/mielipide/art-2000011341393.html
# [mielipide] 13: https://www.hs.fi/mielipide/art-2000011287568.html
# [mielipide] 14: https://www.hs.fi/mielipide/art-2000011338452.html
# [mielipide] 15: https://www.hs.fi/mielipide/art-2000011346742.html
# [mielipide] 16: https://www.hs.fi/mielipide/art-2000011341023.html
# [mielipide] 17: https://www.hs.fi/mielipide/art-2000011318364.html
# [mielipide] 18: https://www.hs.fi/mielipide/art-2000011327955.html
# [mielipide] 19: https://www.hs.fi/mielipide/art-2000011327725.html
# [mielipide] 20: https://www.hs.fi/mielipide/art-2000011310737.html
# [mielipide] 21: https://www.hs.fi/mielipide/art-2000011332181.html
# [mielipide] 22: https://www.hs.fi/mielipide/art-2000011359565.html
# [mielipide] 23: https://www.hs.fi/mielipide/art-2000011350891.html
# [mielipide] 24: https://www.hs.fi/mielipide/art-2000011312998.html
# [mielipide] 25: https://www.hs.fi/mielipide/art-2000011339574.html
# [mielipide] 26: https://www.hs.fi/mielipide/art-2000011350874.html
# [mielipide] 27: https://www.hs.fi/mielipide/art-2000011350159.html
# [mielipide] 28: https://www.hs.fi/mielipide/art-2000011341319.html
# [mielipide] 29: https://www.hs.fi/mielipide/art-2000011324792.html
# [mielipide] 30: https://www.hs.fi/mielipide/art-2000011353448.html
# [mielipide] 31: https://www.hs.fi/mielipide/art-2000011331135.html
# [mielipide] 32: https://www.hs.fi/mielipide/art-2000011300036.html
# [mielipide] 33: https://www.hs.fi/mielipide/art-2000011343265.html
# [mielipide] 34: https://www.hs.fi/mielipide/art-2000011326160.html
# [mielipide] 35: https://www.hs.fi/mielipide/art-2000011359358.html
# [mielipide] 36: https://www.hs.fi/mielipide/art-2000011341537.html
# [mielipide] 37: https://www.hs.fi/mielipide/art-2000011341088.html
# [mielipide] 38: https://www.hs.fi/mielipide/art-2000011342452.html
# [mielipide] 39: https://www.hs.fi/mielipide/art-2000011291135.html
# [mielipide] 40: https://www.hs.fi/mielipide/art-2000011356296.html
# [mielipide] 41: https://www.hs.fi/mielipide/art-2000011330949.html
# [mielipide] 42: https://www.hs.fi/mielipide/art-2000011317123.html
# [mielipide] 43: https://www.hs.fi/mielipide/art-2000011331276.html
# [mielipide] 44: https://www.hs.fi/mielipide/art-2000011342365.html
# [mielipide] 45: https://www.hs.fi/mielipide/art-2000011322208.html
# [mielipide] 46: https://www.hs.fi/mielipide/art-2000011341459.html
# [mielipide] 47: https://www.hs.fi/mielipide/art-2000011333563.html
# [mielipide] 48: https://www.hs.fi/mielipide/art-2000011343161.html
# [mielipide] 49: https://www.hs.fi/mielipide/art-2000011333555.html
# [mielipide] 50: https://www.hs.fi/mielipide/art-2000011347288.html
# [mielipide] 51: https://www.hs.fi/mielipide/art-2000011330942.html
# [mielipide] 52: https://www.hs.fi/mielipide/art-2000011350400.html
# [mielipide] 53: https://www.hs.fi/mielipide/art-2000011357197.html
# [mielipide] 54: https://www.hs.fi/mielipide/art-2000011347229.html
# [mielipide] 55: https://www.hs.fi/mielipide/art-2000011328832.html
# [mielipide] 56: https://www.hs.fi/mielipide/art-2000011350647.html
# [mielipide] 57: https://www.hs.fi/mielipide/art-2000011321953.html
# [mielipide] 58: https://www.hs.fi/mielipide/art-2000011339165.html
# [mielipide] 59: https://www.hs.fi/mielipide/art-2000011327503.html
# [mielipide] 60: https://www.hs.fi/mielipide/art-2000011348058.html
# [mielipide] 61: https://www.hs.fi/mielipide/art-2000011344824.html
# [mielipide] 62: https://www.hs.fi/mielipide/art-2000011339122.html
# [mielipide] 63: https://www.hs.fi/mielipide/art-2000011320258.html
# [mielipide] 64: https://www.hs.fi/mielipide/art-2000011323419.html
# [mielipide] 65: https://www.hs.fi/mielipide/art-2000011341152.html
# [mielipide] 66: https://www.hs.fi/mielipide/art-2000011320948.html
# [mielipide] 67: https://www.hs.fi/mielipide/art-2000011341567.html
# [mielipide] 68: https://www.hs.fi/mielipide/art-2000011329474.html
# [mielipide] 69: https://www.hs.fi/mielipide/art-2000011310697.html
# [mielipide] 70: https://www.hs.fi/mielipide/art-2000011333678.html
# [mielipide] 71: https://www.hs.fi/mielipide/art-2000011340562.html
# [mielipide] 72: https://www.hs.fi/mielipide/art-2000011328998.html
# [mielipide] 73: https://www.hs.fi/mielipide/art-2000011318003.html
# [mielipide] 74: https://www.hs.fi/mielipide/art-2000011314051.html
# [mielipide] 75: https://www.hs.fi/mielipide/art-2000011350323.html
# [mielipide] 76: https://www.hs.fi/mielipide/art-2000011345333.html
# [mielipide] 77: https://www.hs.fi/mielipide/art-2000011322485.html
# [mielipide] 78: https://www.hs.fi/mielipide/art-2000011317828.html
# [mielipide] 79: https://www.hs.fi/mielipide/art-2000011354982.html
# [mielipide] 80: https://www.hs.fi/mielipide/art-2000011343926.html
# [mielipide] 81: https://www.hs.fi/mielipide/art-2000011345160.html
# [mielipide] 82: https://www.hs.fi/mielipide/art-2000011312082.html
# [mielipide] 83: https://www.hs.fi/mielipide/art-2000011348820.html
# [mielipide] 84: https://www.hs.fi/mielipide/art-2000011332236.html
# [mielipide] 85: https://www.hs.fi/mielipide/art-2000011322954.html
# [mielipide] 86: https://www.hs.fi/mielipide/art-2000011344853.html
# [mielipide] 87: https://www.hs.fi/mielipide/art-2000011332030.html
# [mielipide] 88: https://www.hs.fi/mielipide/art-2000011296343.html
# [mielipide] 89: https://www.hs.fi/mielipide/art-2000011319980.html
# [mielipide] 90: https://www.hs.fi/mielipide/art-2000011344876.html
# [mielipide] 91: https://www.hs.fi/mielipide/art-2000011318411.html
# [mielipide] 92: https://www.hs.fi/mielipide/art-2000011329458.html
# [mielipide] 93: https://www.hs.fi/mielipide/art-2000011343817.html
# [mielipide] 94: https://www.hs.fi/mielipide/art-2000011343707.html
# [mielipide] 95: https://www.hs.fi/mielipide/art-2000011316923.html
# [mielipide] 96: https://www.hs.fi/mielipide/art-2000011355096.html
# [mielipide] 97: https://www.hs.fi/mielipide/art-2000011320463.html
# [mielipide] 98: https://www.hs.fi/mielipide/art-2000011330936.html
# [mielipide] 99: https://www.hs.fi/mielipide/art-2000011356347.html
# [mielipide] 100: https://www.hs.fi/mielipide/art-2000011341381.html
# [mielipide] 101: https://www.hs.fi/mielipide/art-2000011341477.html
# Сохранено 101 статей из 'mielipide'
#
# Всего сохранено: 577 статей в hs_articles.csv

# %%
#в текст статей попали и названия, сразу очищаю
#загружаю файл
df = pd.read_csv("hs_articles.csv")

#очищаю третью колонкку, удаляю все до первой черты и саму черту
df.iloc[:, 2] = df.iloc[:, 2].str.replace(r'^.*?\|\s*', '', regex=True)

#сохраняю очищенный файл
df.to_csv("hs_articles_cleaned.csv", index=False)

#остальную предобработку буду делать уже когда будет собран полный корпус.

# %% [markdown]
# Далее код по сути аналогичен для других новостных сайтов.

# %% [markdown]
# 2. KU.fi

# %%
MAX_ARTICLES = 50
CSV_PATH = "ku_articles.csv"

def parse_ku_article(url):
    res = requests.get(url, headers=HEADERS, timeout=10)
    soup = BeautifulSoup(res.content, "html.parser")

    content = soup.find("div", class_="entry-content")
    if not content:
        print(f"Не найден блок в {url}")
        return None

    paragraphs = content.find_all("p")
    text = "\n".join(p.get_text(strip=True) for p in paragraphs if p.get_text(strip=True))
    return text

def collect_ku_articles(max_articles=MAX_ARTICLES):
    base_url = "https://www.ku.fi"
    visited = set()
    collected = 0
    records = []

    res = requests.get(base_url, headers=HEADERS, timeout=10)
    soup = BeautifulSoup(res.content, "html.parser")

    links = [a["href"] for a in soup.find_all("a", href=True) if "/artikkeli/" in a["href"]]

    for link in links:
        if collected >= max_articles:
            break
        url = base_url + link if link.startswith("/") else link
        if url in visited:
            continue

        text = parse_ku_article(url)
        if text and len(text) > 200:
            records.append({
                "source": "ku",
                "url": url,
                "text": text
            })
            print(f"Сохранено {collected+1}: {url}")
            collected += 1

        visited.add(url)
        time.sleep(1)

    df = pd.DataFrame(records)
    df.to_csv(CSV_PATH, index=False, encoding="utf-8")
    print(f"Сохранено {collected} статей в {CSV_PATH}")

collect_ku_articles()
# Out:
# Сохранено 1: https://www.ku.fi/artikkeli/5185343-javier-milein-sota-argentiinan-mediaa-vastaan-emme-vihaa-toimittajia-tarpeeksi
# Сохранено 2: https://www.ku.fi/artikkeli/5182220-ku-listasi-suomen-vaikuttavimmat-vasemmistolaiset-katso-10-nimea
# Сохранено 3: https://www.ku.fi/artikkeli/5181978-noora-kotilaisen-kolumni-tappaminen-sodassa-on-juridisesti-oikeutettua-mutta-lopulta-yksilo-on-yksin-tekojensa-kanssa
# Сохранено 4: https://www.ku.fi/artikkeli/5181613-kaannekohtien-kevat-mita-jai-mieleen-politiikan-alkuvuodesta-2025
# Сохранено 5: https://www.ku.fi/artikkeli/5181174-nelja-nostoa-sotilasliiton-huippukokouksesta-nato-suostui-trumpin-saneluun
# Сохранено 6: https://www.ku.fi/artikkeli/5185886-mathenge-on-kenian-villi-lupiini-ja-jattipalsami-nyt-pakolaisleirin-tytot-ovat-valjastaneet-haitallisen-vieraslajin-hyotykayttoon
# Сохранено 7: https://www.ku.fi/artikkeli/5184944-laivayhteys-helsingista-tallinnaan-tayttaa-60-vuotta-jarisytti-naapurisuhteita
# Сохранено 8: https://www.ku.fi/artikkeli/5184639-huumekauppaa-ja-vakivaltaa-vesijarven-satamassa-timo-sandberg-jatkaa-lahti-sarjaansa-varmoin-ottein
# Сохранено 9: https://www.ku.fi/artikkeli/5184636-chilen-etelan-haava-mapuche-kansan-maakiista-hakee-ratkaisuaan
# Сохранено 10: https://www.ku.fi/artikkeli/5184289-elina-backmanin-saana-havas-dekkarit-kaipaisivat-voimakasta-uusiutumista
# Сохранено 11: https://www.ku.fi/artikkeli/5184287-latinalainen-amerikka-kiristaa-otettaan-kansalaisjarjestoista
# Сохранено 12: https://www.ku.fi/artikkeli/5183466-puolan-rakentama-terasaita-torjuu-idan-uhkaa-valko-venajan-vastaisella-rajalla-mutta-kiusaa-myos-paikallisia
# Сохранено 13: https://www.ku.fi/artikkeli/5183101-roskavuorovesi-vie-turistit-balin-rannoilta-kansalaisjarjeston-varastot-tayttyvat-muovijatteesta
# Сохранено 14: https://www.ku.fi/artikkeli/5182740-zimbabwessa-pienet-jyvat-pelastavat-maanviljelijan-paivan
# Сохранено 15: https://www.ku.fi/artikkeli/5178296-ottawan-sopimus-on-pelastanut-elamia-nyt-miinoista-vientituote
# Сохранено 16: https://www.ku.fi/artikkeli/5181147-toisenlaista-vaenmusiikkia-iskelmallisyyden-ryyppylaulujen-ja-popin-nollari
# Сохранено 17: https://www.ku.fi/artikkeli/5175963-ruotsin-tie-hyvinvointivaltioksi-rakentui-puolivahingossa-lansinaapurin-demareilla-oli-visio-sosialismista-muttei-sen-saavuttamisesta
# Сохранено 18: https://www.ku.fi/artikkeli/5172851-puolustusbudjetti-nousee-huimasti-mista-rahat-vasemmistoliiton-koskela-kysyy
# Сохранено 19: https://www.ku.fi/artikkeli/5183466-puolan-rakentama-terasaita-torjuu-idan-uhkaa-valko-venajan-vastaisella-rajalla-mutta-kiusaa-myos-paikallisia?ref=popular
# Сохранено 20: https://www.ku.fi/artikkeli/5184944-laivayhteys-helsingista-tallinnaan-tayttaa-60-vuotta-jarisytti-naapurisuhteita?ref=popular
# Сохранено 21: https://www.ku.fi/artikkeli/5185886-mathenge-on-kenian-villi-lupiini-ja-jattipalsami-nyt-pakolaisleirin-tytot-ovat-valjastaneet-haitallisen-vieraslajin-hyotykayttoon?ref=popular
# Сохранено 22: https://www.ku.fi/artikkeli/4989174-1800-luvun-taudit-palanneet-britanniaan-yhtena-syyna-sosiaaliturvan-ja-julkisen-terveydenhuollon-leikkaukset?ref=popular
# Сохранено 23: https://www.ku.fi/artikkeli/5183101-roskavuorovesi-vie-turistit-balin-rannoilta-kansalaisjarjeston-varastot-tayttyvat-muovijatteesta?ref=popular
# Сохранено 24: https://www.ku.fi/artikkeli/5181668-rukoilen-ala-aanesta-demareita
# Сохранено 25: https://www.ku.fi/artikkeli/5174156-elamanpuolustajan-soturikunnia
# Сохранено 26: https://www.ku.fi/artikkeli/5164046-emme-ole-valmiita-fasismin-paluuseen
# Сохранено 27: https://www.ku.fi/artikkeli/onko-nuorille-tarjolla-muutakin-kuin-sodanajan-sijoituspaikka
# Сохранено 28: https://www.ku.fi/artikkeli/milta-antifasistinen-ulkopolitiikka-nayttaa
# Сохранено 29: https://www.ku.fi/artikkeli/tiede-luo-toivoa-kun-maailma-myllertaa
# Сохранено 30: https://www.ku.fi/artikkeli/250-miljardia-syyta-tukea-ukrainaa
# Сохранено 30 статей в ku_articles.csv

# %% [markdown]
# 3.  Hämeenlinnakaupunkiuutiset

# %%
MAX_ARTICLES = 50
CSV_PATH = "hameenlinna_articles.csv"

def parse_article(url):
    res = requests.get(url, headers=HEADERS, timeout=10)
    soup = BeautifulSoup(res.content, "html.parser")

    content = soup.find("div", class_="diks-article__inner-content")
    if not content:
        return None

    paragraphs = content.find_all("p")
    text = "\n".join(p.get_text(strip=True) for p in paragraphs if p.get_text(strip=True))
    return text if len(text.split()) >= 50 else None

def collect_articles(max_articles=MAX_ARTICLES):
    base_url = "https://www.hameenlinnankaupunkiuutiset.fi"
    res = requests.get(base_url, headers=HEADERS, timeout=10)
    soup = BeautifulSoup(res.content, "html.parser")

    links = [a["href"] for a in soup.find_all("a", href=True)
             if "/paikalliset/" in a["href"] and any(char.isdigit() for char in a["href"].split("/")[-1])]
    links = list(dict.fromkeys(links))

    records = []
    visited = set()

    for link in links:
        if len(records) >= max_articles:
            break
        url = base_url + link if link.startswith("/") else link
        if url in visited:
            continue

        text = parse_article(url)
        if text:
            records.append({
                "source": "hameenlinna",
                "url": url,
                "text": text
            })
            print(f"Сохранено {len(records)}: {url}")

        visited.add(url)
        time.sleep(1)

    pd.DataFrame(records).to_csv(CSV_PATH, index=False, encoding="utf-8")
    print(f"Сохранено {len(records)} статей в {CSV_PATH}")

collect_articles()
# Out:
# Сохранено 1: https://www.hameenlinnankaupunkiuutiset.fi/paikalliset/8629711
# Сохранено 2: https://www.hameenlinnankaupunkiuutiset.fi/paikalliset/8629583
# Сохранено 3: https://www.hameenlinnankaupunkiuutiset.fi/paikalliset/8603797
# Сохранено 4: https://www.hameenlinnankaupunkiuutiset.fi/paikalliset/8629848
# Сохранено 5: https://www.hameenlinnankaupunkiuutiset.fi/paikalliset/8629918
# Сохранено 6: https://www.hameenlinnankaupunkiuutiset.fi/paikalliset/8609968
# Сохранено 7: https://www.hameenlinnankaupunkiuutiset.fi/paikalliset/8609951
# Сохранено 8: https://www.hameenlinnankaupunkiuutiset.fi/paikalliset/8593582
# Сохранено 9: https://www.hameenlinnankaupunkiuutiset.fi/paikalliset/8629903
# Сохранено 10: https://www.hameenlinnankaupunkiuutiset.fi/paikalliset/8629891
# Сохранено 11: https://www.hameenlinnankaupunkiuutiset.fi/paikalliset/8615169
# Сохранено 12: https://www.hameenlinnankaupunkiuutiset.fi/paikalliset/8614752
# Сохранено 13: https://www.hameenlinnankaupunkiuutiset.fi/paikalliset/8610222
# Сохранено 14: https://www.hameenlinnankaupunkiuutiset.fi/paikalliset/8610131
# Сохранено 15: https://www.hameenlinnankaupunkiuutiset.fi/paikalliset/8610163
# Сохранено 16: https://www.hameenlinnankaupunkiuutiset.fi/paikalliset/8610117
# Сохранено 17: https://www.hameenlinnankaupunkiuutiset.fi/paikalliset/8604030
# Сохранено 18: https://www.hameenlinnankaupunkiuutiset.fi/paikalliset/8610123
# Сохранено 19: https://www.hameenlinnankaupunkiuutiset.fi/paikalliset/8609983
# Сохранено 20: https://www.hameenlinnankaupunkiuutiset.fi/paikalliset/8594518
# Сохранено 21: https://www.hameenlinnankaupunkiuutiset.fi/paikalliset/8594421
# Сохранено 22: https://www.hameenlinnankaupunkiuutiset.fi/paikalliset/8584308
# Сохранено 23: https://www.hameenlinnankaupunkiuutiset.fi/paikalliset/8593806
# Сохранено 23 статей в hameenlinna_articles.csv

# %%
df = pd.read_csv("hameenlinna_articles.csv")

#удаляю фразу "Lue lisää aiheesta" из колонки с текстом
df["text"] = df["text"].str.replace("Lue lisää aiheesta", "", regex=False)

#сохраняю
df.to_csv("hameenlinna_articles_cleaned.csv", index=False)

# %% [markdown]
# 4. Heili.fi

# %%
MAX_ARTICLES = 50
CSV_PATH = "heili_articles.csv"

def parse_heili_article(url):
    res = requests.get(url, headers=HEADERS, timeout=10)
    soup = BeautifulSoup(res.content, "html.parser")

    content = soup.find("div", class_="diks-article__inner-content")
    if not content:
        print(f"Не найден блок в {url}")
        return None

    paragraphs = content.find_all("p")
    text = "\n".join(p.get_text(strip=True) for p in paragraphs if p.get_text(strip=True))
    return text if len(text.split()) >= 50 else None

def collect_heili_articles(max_articles=MAX_ARTICLES):
    base_url = "https://www.heili.fi"
    visited = set()
    collected = 0
    records = []

    res = requests.get(base_url, headers=HEADERS, timeout=10)
    soup = BeautifulSoup(res.content, "html.parser")

    links = [a["href"] for a in soup.find_all("a", href=True)
             if "/paikalliset/" in a["href"] and any(char.isdigit() for char in a["href"].split("/")[-1])]

    for link in links:
        if collected >= max_articles:
            break
        url = base_url + link if link.startswith("/") else link
        if url in visited:
            continue

        text = parse_heili_article(url)
        if text:
            records.append({
                "source": "heili",
                "url": url,
                "text": text
            })
            print(f"Сохранено {collected + 1}: {url}")
            collected += 1

        visited.add(url)
        time.sleep(1)

    df = pd.DataFrame(records)
    df.to_csv(CSV_PATH, index=False, encoding="utf-8")
    print(f"Сохранено {collected} статей в {CSV_PATH}")

collect_heili_articles()
# Out:
# Сохранено 1: https://www.heili.fi/paikalliset/8600007
# Сохранено 2: https://www.heili.fi/paikalliset/8580276
# Сохранено 3: https://www.heili.fi/paikalliset/8600434
# Сохранено 4: https://www.heili.fi/paikalliset/8654118
# Сохранено 5: https://www.heili.fi/paikalliset/8645334
# Сохранено 6: https://www.heili.fi/paikalliset/8645303
# Сохранено 7: https://www.heili.fi/paikalliset/8643125
# Сохранено 8: https://www.heili.fi/paikalliset/8580194
# Сохранено 9: https://www.heili.fi/paikalliset/8630242
# Сохранено 10: https://www.heili.fi/paikalliset/8632992
# Сохранено 11: https://www.heili.fi/paikalliset/8632929
# Сохранено 12: https://www.heili.fi/paikalliset/8629659
# Сохранено 13: https://www.heili.fi/paikalliset/8627573
# Сохранено 14: https://www.heili.fi/paikalliset/8619079
# Сохранено 15: https://www.heili.fi/paikalliset/8627581
# Сохранено 16: https://www.heili.fi/paikalliset/8627393
# Сохранено 17: https://www.heili.fi/paikalliset/8584425
# Сохранено 18: https://www.heili.fi/paikalliset/8620722
# Сохранено 19: https://www.heili.fi/paikalliset/8623149
# Сохранено 20: https://www.heili.fi/paikalliset/8621343
# Сохранено 21: https://www.heili.fi/paikalliset/8620702
# Сохранено 22: https://www.heili.fi/paikalliset/8611973
# Сохранено 23: https://www.heili.fi/paikalliset/8614916
# Сохранено 24: https://www.heili.fi/paikalliset/8614237
# Сохранено 25: https://www.heili.fi/paikalliset/8613181
# Сохранено 26: https://www.heili.fi/paikalliset/8600289
# Сохранено 27: https://www.heili.fi/paikalliset/8611851
# Сохранено 28: https://www.heili.fi/paikalliset/8610277
# Сохранено 29: https://www.heili.fi/paikalliset/8594699
# Сохранено 30: https://www.heili.fi/paikalliset/8607822
# Сохранено 30 статей в heili_articles.csv

# %%
df = pd.read_csv("heili_articles.csv")

#удаляю фразу "Lue lisää aiheesta" из колонки с текстом
df["text"] = df["text"].str.replace("Lue lisää aiheesta", "", regex=False)

#сохраняю
df.to_csv("heili_articles_cleaned.csv", index=False)

# %% [markdown]
# 5. Karkkilalainen

# %%
MAX_ARTICLES = 50
CSV_PATH = "karkkilalainen_articles.csv"

def parse_karkkilalainen_article(url):
    res = requests.get(url, headers=HEADERS, timeout=10)
    soup = BeautifulSoup(res.content, "html.parser")

    content = soup.find("div", class_="diks-article__inner-content")
    if not content:
        print(f"Не найден блок в {url}")
        return None

    paragraphs = content.find_all("p")
    text = "\n".join(p.get_text(strip=True) for p in paragraphs if p.get_text(strip=True))
    return text

def collect_karkkilalainen_articles(max_articles=MAX_ARTICLES):
    base_url = "https://www.karkkilalainen.fi"
    visited = set()
    collected = 0
    records = []

    res = requests.get(base_url, headers=HEADERS, timeout=10)
    soup = BeautifulSoup(res.content, "html.parser")

    links = [a["href"] for a in soup.find_all("a", href=True)
             if "/paikalliset/" in a["href"] and any(char.isdigit() for char in a["href"].split("/")[-1])]

    for link in links:
        if collected >= max_articles:
            break
        url = base_url + link if link.startswith("/") else link
        if url in visited:
            continue

        text = parse_karkkilalainen_article(url)
        if text and len(text) > 200:
            records.append({
                "source": "karkkilalainen",
                "url": url,
                "text": text
            })
            print(f"Сохранено {collected + 1}: {url}")
            collected += 1

        visited.add(url)
        time.sleep(1)

    df = pd.DataFrame(records)
    df.to_csv(CSV_PATH, index=False, encoding="utf-8")
    print(f"Сохранено {collected} статей в {CSV_PATH}")

collect_karkkilalainen_articles()
# Out:
# Сохранено 1: https://www.karkkilalainen.fi/paikalliset/8568785
# Сохранено 2: https://www.karkkilalainen.fi/paikalliset/8673870
# Сохранено 3: https://www.karkkilalainen.fi/paikalliset/8674497
# Сохранено 4: https://www.karkkilalainen.fi/paikalliset/8670609
# Сохранено 5: https://www.karkkilalainen.fi/paikalliset/8669579
# Сохранено 6: https://www.karkkilalainen.fi/paikalliset/8668574
# Сохранено 7: https://www.karkkilalainen.fi/paikalliset/8668265
# Сохранено 8: https://www.karkkilalainen.fi/paikalliset/8659577
# Сохранено 9: https://www.karkkilalainen.fi/paikalliset/8668290
# Сохранено 10: https://www.karkkilalainen.fi/paikalliset/8667704
# Сохранено 11: https://www.karkkilalainen.fi/paikalliset/8664870
# Сохранено 12: https://www.karkkilalainen.fi/paikalliset/8658445
# Сохранено 13: https://www.karkkilalainen.fi/paikalliset/8656327
# Сохранено 14: https://www.karkkilalainen.fi/paikalliset/8655173
# Сохранено 15: https://www.karkkilalainen.fi/paikalliset/8658698
# Сохранено 16: https://www.karkkilalainen.fi/paikalliset/8658080
# Сохранено 17: https://www.karkkilalainen.fi/paikalliset/8655310
# Сохранено 18: https://www.karkkilalainen.fi/paikalliset/8651235
# Сохранено 19: https://www.karkkilalainen.fi/paikalliset/8649340
# Сохранено 20: https://www.karkkilalainen.fi/paikalliset/8648133
# Сохранено 21: https://www.karkkilalainen.fi/paikalliset/8641270
# Сохранено 22: https://www.karkkilalainen.fi/paikalliset/8640830
# Сохранено 23: https://www.karkkilalainen.fi/paikalliset/8640372
# Сохранено 24: https://www.karkkilalainen.fi/paikalliset/8636898
# Сохранено 25: https://www.karkkilalainen.fi/paikalliset/8640271
# Сохранено 26: https://www.karkkilalainen.fi/paikalliset/8645871
# Сохранено 27: https://www.karkkilalainen.fi/paikalliset/8639284
# Сохранено 28: https://www.karkkilalainen.fi/paikalliset/8637416
# Сохранено 29: https://www.karkkilalainen.fi/paikalliset/8628783
# Сохранено 30: https://www.karkkilalainen.fi/paikalliset/8634222
# Сохранено 30 статей в karkkilalainen_articles.csv

# %%
df = pd.read_csv("karkkilalainen_articles.csv")

#удаляю фразу "Lue lisää aiheesta" из колонки с текстом
df["text"] = df["text"].str.replace("Lue lisää aiheesta", "", regex=False)

#сохраняю
df.to_csv("karkkilalainen_articles_cleaned.csv", index=False)

# %% [markdown]
# 6. Pkank

# %%
MAX_ARTICLES = 50
CSV_PATH = "pkank_articles.csv"

def parse_pkank_article(url):
    res = requests.get(url, headers=HEADERS, timeout=10)
    soup = BeautifulSoup(res.content, "html.parser")

    content = soup.find("div", class_="ank-text")
    if not content:
        print(f"Не найден блок в {url}")
        return None

    paragraphs = content.find_all("p", class_="teksti")
    text = "\n".join(p.get_text(strip=True) for p in paragraphs if p.get_text(strip=True))
    return text if len(text) > 200 else None

def collect_pkank_articles(max_articles=MAX_ARTICLES):
    base_url = "https://www.pkank.fi"
    visited = set()
    collected = 0
    records = []

    res = requests.get(base_url, headers=HEADERS, timeout=10)
    soup = BeautifulSoup(res.content, "html.parser")

    links = [a["href"] for a in soup.find_all("a", href=True)
             if "/uutiset/" in a["href"] and any(char.isdigit() for char in a["href"].split("/")[-1])]

    for link in links:
        if collected >= max_articles:
            break
        url = base_url + link if link.startswith("/") else link
        if url in visited:
            continue

        text = parse_pkank_article(url)
        if text:
            records.append({
                "source": "pkank",
                "url": url,
                "text": text
            })
            print(f"Сохранено {collected+1}: {url}")
            collected += 1

        visited.add(url)
        time.sleep(1)

    df = pd.DataFrame(records)
    df.to_csv(CSV_PATH, index=False, encoding="utf-8")
    print(f"\nСохранено {collected} статей в {CSV_PATH}")

collect_pkank_articles()
# Out:
# Сохранено 1: https://www.pkank.fi/uutiset/anjalassa-ja-voikkaalla-torjutaan-vieraskasveja-talkoilla-6.19.36938.62aa160531
# Сохранено 2: https://www.pkank.fi/uutiset/wiipurintien-markkinat-vie-jalleen-keskiajan-tunnelmiin-6.19.36934.7c8ceec77e
# Сохранено 3: https://www.pkank.fi/uutiset/tyo-kymenlaakson-luonnon-eteen-toi-ymparistopalkinnon-6.19.36823.498d07553b
# Сохранено 4: https://www.pkank.fi/uutiset/kiinteistoilla-elinvoimaa-kotkaan-6.19.35521.a4e3849cab
# Сохранено 5: https://www.pkank.fi/uutiset/korjausurakka-sulkee-alikulkukaytavan-viikoksi-kouvolan-lehtomaessa-6.19.36935.6107a5f4b3
# Сохранено 6: https://www.pkank.fi/uutiset/kotkalaislahtoinen-that-band-from-finland-voitti-suomen-paras-kantribiisi-kilpailun-6.19.36939.9290fff906
# Сохранено 7: https://www.pkank.fi/uutiset/mielipide-suomi-tarvitsee-positiivista-maahanmuuttoa-ei-rasismia-6.19.36931.6d1d994423
# Сохранено 8: https://www.pkank.fi/uutiset/mika-on-kouvolan-keskustateko-2025--aanestys-on-kaynnissa-6.19.36936.0f7d61e2d3
#
# Сохранено 8 статей в pkank_articles.csv

# %% [markdown]
# На данный момент у нас есть 6 отдельных csv файлов для каждой газеты - объединяем их вместе.

# %%
file_paths = [
    "heili_articles_cleaned.csv",
    "hameenlinna_articles_cleaned.csv",
    "karkkilalainen_articles_cleaned.csv",
    "ku_articles.csv",
    "hs_articles_cleaned.csv",
    "pkank_articles.csv"
]

dfs = [pd.read_csv(path) for path in file_paths]
for df, path in zip(dfs, file_paths):
    df["source_file"] = path

combined_df = pd.concat(dfs, ignore_index=True)
combined_df.to_csv("all_articles_combined.csv", index=False, encoding="utf-8")

print(f"Объединено")
# Out:
# Объединено

# %% [markdown]
# # Сбор книжного корпуса

# %% [markdown]
# Помимо новостных текстов, я также включаю в корпус материалы из учебной и художественной литературы. Это позволяет расширить языковое разнообразие и сделать корпус полезным для генерации заданий с разными уровнями сложности и жанрами текста.
#
#
#
# *  Источниками послужили:
#
# PDF-файлы с адаптированными книгами на финском языке (короткие, детские рассказы)
#
# Bilingual-файлы (финско-русские), из которых извлекаются только финские реплики
#
# Все тексты проходят фильтрацию по языку: мы исключаем строки с русскими символами, чтобы сохранить только финскую часть текста.
#
# Художественные тексты намеренно не использовались в этом этапе, поскольку они часто содержат устаревшую или нестандартную лексику, а также неестественные для повседневного языка конструкции.

# %%
#установка библиотек для работы с пдф, ворд файлами, os для работы с файлами
# !pip install pymupdf
# !pip install python-docx
import fitz
from docx import Document
import os
# Out:
# Collecting pymupdf
#   Downloading pymupdf-1.26.3-cp39-abi3-manylinux_2_28_x86_64.whl.metadata (3.4 kB)
# Downloading pymupdf-1.26.3-cp39-abi3-manylinux_2_28_x86_64.whl (24.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.1/24.1 MB 58.1 MB/s eta 0:00:00
# Installing collected packages: pymupdf
# Successfully installed pymupdf-1.26.3
# Collecting python-docx
#   Downloading python_docx-1.2.0-py3-none-any.whl.metadata (2.0 kB)
# Requirement already satisfied: lxml>=3.1.0 in /usr/local/lib/python3.11/dist-packages (from python-docx) (5.4.0)
# Requirement already satisfied: typing_extensions>=4.9.0 in /usr/local/lib/python3.11/dist-packages (from python-docx) (4.14.1)
# Downloading python_docx-1.2.0-py3-none-any.whl (252 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 253.0/253.0 kB 3.2 MB/s eta 0:00:00
# Installing collected packages: python-docx
# Successfully installed python-docx-1.2.0

# %% [markdown]
# Открываю пдф и извлекаю текст со всех страниц (вручную удаляю первую ненужную страницу)

# %%
def extract_text_from_pdf(pdf_path):
    text = ""
    with fitz.open(pdf_path) as doc:
        for page_num, page in enumerate(doc):
            if page_num == 0:
                continue  # пропускаем первую страницу, т.к. на ней просто содержание
            text += page.get_text()
    return text

# %% [markdown]
# Тоже самое для другой книги, но еще удаляем все кириллические символы, т.к. книга сразу с переводом

# %%
def extract_finnish_from_pdf(pdf_path):
    doc = fitz.open(pdf_path)
    text = ""

    for page_num in range(0, len(doc)):
        page = doc.load_page(page_num)
        page_text = page.get_text()
        for line in page_text.splitlines():
            line = line.strip()
            if line and not re.search(r'[а-яА-ЯёЁ]', line):
                text += line + "\n"

    return text

# %% [markdown]
# Обработка ворд-файла

# %%
def extract_finnish_from_bilingual(docx_path):
    doc = Document(docx_path)
    text = ""
    for para in doc.paragraphs:
        line = para.text.strip()
        if line and not re.search(r'[а-яА-ЯёЁ]', line):  # исключаем строки с кириллицей
            text += line + "\n"
    return text

# %% [markdown]
# Объединяю все в один файл, разделяя при этом на чанки (не более 10 000 слов), чтобы в дальнейшем было легче обрабатывать данные

# %%
# !pip install stanza
# Out:
# Collecting stanza
#   Downloading stanza-1.10.1-py3-none-any.whl.metadata (13 kB)
# Collecting emoji (from stanza)
#   Downloading emoji-2.14.1-py3-none-any.whl.metadata (5.7 kB)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from stanza) (2.0.2)
# Requirement already satisfied: protobuf>=3.15.0 in /usr/local/lib/python3.11/dist-packages (from stanza) (5.29.5)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (from stanza) (2.32.3)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from stanza) (3.5)
# Requirement already satisfied: torch>=1.3.0 in /usr/local/lib/python3.11/dist-packages (from stanza) (2.6.0+cu124)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.11/dist-packages (from stanza) (4.67.1)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from torch>=1.3.0->stanza) (3.18.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.11/dist-packages (from torch>=1.3.0->stanza) (4.14.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from torch>=1.3.0->stanza) (3.1.6)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.11/dist-packages (from torch>=1.3.0->stanza) (2025.3.2)
# Collecting nvidia-cuda-nvrtc-cu12==12.4.127 (from torch>=1.3.0->stanza)
#   Downloading nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-runtime-cu12==12.4.127 (from torch>=1.3.0->stanza)
#   Downloading nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-cupti-cu12==12.4.127 (from torch>=1.3.0->stanza)
#   Downloading nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cudnn-cu12==9.1.0.70 (from torch>=1.3.0->stanza)
#   Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cublas-cu12==12.4.5.8 (from torch>=1.3.0->stanza)
#   Downloading nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cufft-cu12==11.2.1.3 (from torch>=1.3.0->stanza)
#   Downloading nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-curand-cu12==10.3.5.147 (from torch>=1.3.0->stanza)
#   Downloading nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cusolver-cu12==11.6.1.9 (from torch>=1.3.0->stanza)
#   Downloading nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cusparse-cu12==12.3.1.170 (from torch>=1.3.0->stanza)
#   Downloading nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.6.2 in /usr/local/lib/python3.11/dist-packages (from torch>=1.3.0->stanza) (0.6.2)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /usr/local/lib/python3.11/dist-packages (from torch>=1.3.0->stanza) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=1.3.0->stanza) (12.4.127)
# Collecting nvidia-nvjitlink-cu12==12.4.127 (from torch>=1.3.0->stanza)
#   Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Requirement already satisfied: triton==3.2.0 in /usr/local/lib/python3.11/dist-packages (from torch>=1.3.0->stanza) (3.2.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.11/dist-packages (from torch>=1.3.0->stanza) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy==1.13.1->torch>=1.3.0->stanza) (1.3.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests->stanza) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests->stanza) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests->stanza) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests->stanza) (2025.6.15)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->torch>=1.3.0->stanza) (3.0.2)
# Downloading stanza-1.10.1-py3-none-any.whl (1.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 14.4 MB/s eta 0:00:00
# Downloading nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl (363.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 4.4 MB/s eta 0:00:00
# Downloading nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (13.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 104.0 MB/s eta 0:00:00
# Downloading nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (24.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 64.4 MB/s eta 0:00:00
# Downloading nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (883 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 44.5 MB/s eta 0:00:00
# Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl (664.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 1.3 MB/s eta 0:00:00
# Downloading nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl (211.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 2.8 MB/s eta 0:00:00
# Downloading nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl (56.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 14.2 MB/s eta 0:00:00
# Downloading nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl (127.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 7.6 MB/s eta 0:00:00
# Downloading nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl (207.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 3.9 MB/s eta 0:00:00
# Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (21.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 34.8 MB/s eta 0:00:00
# Downloading emoji-2.14.1-py3-none-any.whl (590 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 590.6/590.6 kB 26.2 MB/s eta 0:00:00
# Installing collected packages: nvidia-nvjitlink-cu12, nvidia-curand-cu12, nvidia-cufft-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, emoji, nvidia-cusparse-cu12, nvidia-cudnn-cu12, nvidia-cusolver-cu12, stanza
#   Attempting uninstall: nvidia-nvjitlink-cu12
#     Found existing installation: nvidia-nvjitlink-cu12 12.5.82
#     Uninstalling nvidia-nvjitlink-cu12-12.5.82:
#       Successfully uninstalled nvidia-nvjitlink-cu12-12.5.82
#   Attempting uninstall: nvidia-curand-cu12
#     Found existing installation: nvidia-curand-cu12 10.3.6.82
#     Uninstalling nvidia-curand-cu12-10.3.6.82:
#       Successfully uninstalled nvidia-curand-cu12-10.3.6.82
#   Attempting uninstall: nvidia-cufft-cu12
#     Found existing installation: nvidia-cufft-cu12 11.2.3.61
#     Uninstalling nvidia-cufft-cu12-11.2.3.61:
#       Successfully uninstalled nvidia-cufft-cu12-11.2.3.61
#   Attempting uninstall: nvidia-cuda-runtime-cu12
#     Found existing installation: nvidia-cuda-runtime-cu12 12.5.82
#     Uninstalling nvidia-cuda-runtime-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-runtime-cu12-12.5.82
#   Attempting uninstall: nvidia-cuda-nvrtc-cu12
#     Found existing installation: nvidia-cuda-nvrtc-cu12 12.5.82
#     Uninstalling nvidia-cuda-nvrtc-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-nvrtc-cu12-12.5.82
#   Attempting uninstall: nvidia-cuda-cupti-cu12
#     Found existing installation: nvidia-cuda-cupti-cu12 12.5.82
#     Uninstalling nvidia-cuda-cupti-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-cupti-cu12-12.5.82
#   Attempting uninstall: nvidia-cublas-cu12
#     Found existing installation: nvidia-cublas-cu12 12.5.3.2
#     Uninstalling nvidia-cublas-cu12-12.5.3.2:
#       Successfully uninstalled nvidia-cublas-cu12-12.5.3.2
#   Attempting uninstall: nvidia-cusparse-cu12
#     Found existing installation: nvidia-cusparse-cu12 12.5.1.3
#     Uninstalling nvidia-cusparse-cu12-12.5.1.3:
#       Successfully uninstalled nvidia-cusparse-cu12-12.5.1.3
#   Attempting uninstall: nvidia-cudnn-cu12
#     Found existing installation: nvidia-cudnn-cu12 9.3.0.75
#     Uninstalling nvidia-cudnn-cu12-9.3.0.75:
#       Successfully uninstalled nvidia-cudnn-cu12-9.3.0.75
#   Attempting uninstall: nvidia-cusolver-cu12
#     Found existing installation: nvidia-cusolver-cu12 11.6.3.83
#     Uninstalling nvidia-cusolver-cu12-11.6.3.83:
#       Successfully uninstalled nvidia-cusolver-cu12-11.6.3.83
# Successfully installed emoji-2.14.1 nvidia-cublas-cu12-12.4.5.8 nvidia-cuda-cupti-cu12-12.4.127 nvidia-cuda-nvrtc-cu12-12.4.127 nvidia-cuda-runtime-cu12-12.4.127 nvidia-cudnn-cu12-9.1.0.70 nvidia-cufft-cu12-11.2.1.3 nvidia-curand-cu12-10.3.5.147 nvidia-cusolver-cu12-11.6.1.9 nvidia-cusparse-cu12-12.3.1.170 nvidia-nvjitlink-cu12-12.4.127 stanza-1.10.1

# %%
import os
import stanza

#скачиваю stanza для финского языка, чтобы разбить сплошной текст на предложения
stanza.download("fi")
#нужна только токенизация
nlp = stanza.Pipeline("fi", processors="tokenize", tokenize_no_ssplit=False)

#функция для разделения текста на предложения
def split_into_sentences(text):
    doc = nlp(text)
    return [sent.text for sent in doc.sentences]

#функция для разделения текста на чанки
def save_texts_sentence_chunks(output_dir, *texts, chunk_size=10000):
    #создаю папку для вывода частей текстов
    os.makedirs(output_dir, exist_ok=True)
    #список для хранения всех предложений
    all_sentences = []

    #прохожу по всем текстам, разбиваю каждый текст на предложения и добавляю их в список
    for text in texts:
        all_sentences.extend(split_into_sentences(text))

    #список для хранения чанков
    chunks = []
    #временный список для текущего чанка
    current_chunk = []
    #счетчик слов для текущего чанка
    current_word_count = 0
    #счетчик чанков, для того, чтобы потом назвать чанки с правильнйо нумерацией
    chunk_counter = 1

    #прохожу по предложениям, считаю слова в предложении
    for sent in all_sentences:
        sent_word_count = len(sent.split())
        #если добавление предложения ведет к превышению размера чанка, то формируем текст текущей части, сохраняем в ДатаФрейм и записываем в файл
        if current_word_count + sent_word_count > chunk_size:
            chunk_text = " ".join(current_chunk)
            df = pd.DataFrame({"text": [chunk_text]})
            filename = os.path.join(output_dir, f"text_chunk_{chunk_counter}.csv")
            df.to_csv(filename, index=False)
            print(f"Сохранён файл: {filename}, слов: {current_word_count}")
            #увеличиваю счетчик чанков и сбрастываю временный список для текущего чанка и количество слов в текущем чанке
            chunk_counter += 1
            current_chunk = []
            current_word_count = 0
        #добавляю предложение в текущую часть (чанк)
        current_chunk.append(sent)
        #увеличиваю количество слов в текущей части (чанке)
        current_word_count += sent_word_count

    #если после всего в конце останется неполная часть, то ее тоже сохраняем
    if current_chunk:
        chunk_text = " ".join(current_chunk)
        df = pd.DataFrame({"text": [chunk_text]})
        filename = os.path.join(output_dir, f"text_chunk_{chunk_counter}.csv")
        df.to_csv(filename, index=False)
        print(f"Сохранён файл: {filename}, слов: {current_word_count}")
# Out:
# Downloading https://raw.githubusercontent.com/stanfordnlp/stanza-resources/main/resources_1.10.0.json:   0%|  …
# INFO:stanza:Downloaded file to /root/stanza_resources/resources.json
# INFO:stanza:Downloading default packages for language: fi (Finnish) ...
# INFO:stanza:File exists: /root/stanza_resources/fi/default.zip
# INFO:stanza:Finished downloading models and saved to /root/stanza_resources
# INFO:stanza:Checking for updates to resources.json in case models have been updated.  Note: this behavior can be turned off with download_method=None or download_method=DownloadMethod.REUSE_RESOURCES
# Downloading https://raw.githubusercontent.com/stanfordnlp/stanza-resources/main/resources_1.10.0.json:   0%|  …
# INFO:stanza:Downloaded file to /root/stanza_resources/resources.json
# WARNING:stanza:Language fi package default expects mwt, which has been added
# INFO:stanza:Loading these models for language: fi (Finnish):
# =======================
# | Processor | Package |
# -----------------------
# | tokenize  | tdt     |
# | mwt       | tdt     |
# =======================
#
# INFO:stanza:Using device: cpu
# INFO:stanza:Loading: tokenize
# INFO:stanza:Loading: mwt
# INFO:stanza:Done loading processors!

# %% [markdown]
# Собственно, запускаем все наши функции в основном блоке

# %%
if __name__ == "__main__":
    pdf_text = extract_text_from_pdf("Sbornik-knig-na-uproshchyonnom-finskom-yazyke-selkokieli-Finnish-_RuLit_Me.pdf")
    muumi_text = extract_finnish_from_pdf("Jansson_Muumipeikko_bilingua.pdf")
    finrus_text = extract_finnish_from_bilingual("Финские тексты.docx")
    adapted_text = extract_finnish_from_bilingual("адаптированные худ. тексты.docx")

    save_texts_sentence_chunks("output_chunks", pdf_text, muumi_text, finrus_text, adapted_text, chunk_size=10000)
# Out:
# Сохранён файл: output_chunks/text_chunk_1.csv, слов: 9993
# Сохранён файл: output_chunks/text_chunk_2.csv, слов: 9994
# Сохранён файл: output_chunks/text_chunk_3.csv, слов: 9997
# Сохранён файл: output_chunks/text_chunk_4.csv, слов: 10000
# Сохранён файл: output_chunks/text_chunk_5.csv, слов: 9999
# Сохранён файл: output_chunks/text_chunk_6.csv, слов: 9998
# Сохранён файл: output_chunks/text_chunk_7.csv, слов: 9999
# Сохранён файл: output_chunks/text_chunk_8.csv, слов: 9990
# Сохранён файл: output_chunks/text_chunk_9.csv, слов: 9993
# Сохранён файл: output_chunks/text_chunk_10.csv, слов: 10000
# Сохранён файл: output_chunks/text_chunk_11.csv, слов: 10000
# Сохранён файл: output_chunks/text_chunk_12.csv, слов: 9997
# Сохранён файл: output_chunks/text_chunk_13.csv, слов: 9997
# Сохранён файл: output_chunks/text_chunk_14.csv, слов: 9994
# Сохранён файл: output_chunks/text_chunk_15.csv, слов: 9996
# Сохранён файл: output_chunks/text_chunk_16.csv, слов: 9986
# Сохранён файл: output_chunks/text_chunk_17.csv, слов: 10000
# Сохранён файл: output_chunks/text_chunk_18.csv, слов: 9987
# Сохранён файл: output_chunks/text_chunk_19.csv, слов: 9998
# Сохранён файл: output_chunks/text_chunk_20.csv, слов: 9990
# Сохранён файл: output_chunks/text_chunk_21.csv, слов: 9994
# Сохранён файл: output_chunks/text_chunk_22.csv, слов: 4375

# %% [markdown]
# Загружаю новостной и книжный корпуса и объединяю в единый корпус.

# %%
import pandas as pd

df_articles = pd.read_csv("all_articles_combined.csv")

df_articles = df_articles.loc[:, ~df_articles.columns.duplicated()]
df_articles = df_articles.rename(columns={"text_raw": "text"})
df_articles = df_articles[["text"]]
df_articles["source"] = "news"

chunk_dir = "output_chunks"
chunk_files = sorted([f for f in os.listdir(chunk_dir) if f.endswith(".csv")])

lesson_chunks = []
for file in chunk_files:
    df = pd.read_csv(os.path.join(chunk_dir, file))
    df["source"] = "book"
    lesson_chunks.append(df)

df_lessons = pd.concat(lesson_chunks, ignore_index=True)

df_combined = pd.concat([df_articles, df_lessons], ignore_index=True)

df_combined.to_csv("complete_corpus.csv", index=False, encoding="utf-8")

# %% [markdown]
# Счетчик слов:

# %%
import pandas as pd

df = pd.read_csv("complete_corpus.csv")

def count_words(text):
    return len(str(text).split())

df["word_count"] = df["text"].apply(count_words)

total_words = df["word_count"].sum()

print(f"Общее количество слов в корпусе: {total_words}")
# Out:
# Общее количество слов в корпусе: 449861
